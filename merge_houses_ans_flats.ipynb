# %%
import numpy as np
import pandas as pd

# %%
flats=pd.read_csv('flats_cleaned.csv')
houses=pd.read_csv('house_cleaned.csv')

# %%
df=pd.concat([flats,houses],ignore_index=True)

# %%
df=df.sample(df.shape[0],ignore_index=True)

# %%
df.sample(5)
# Out:
#      property_type                          society      sector  price  \
# 20            flat            signature global park  sohna road   0.55
# 3147          flat           bptp freedom park life   sector 57   5.50
# 2354          flat                       paras dews  sector 106   1.34
# 3594         house               emaar mgf marbella   sector 66    NaN
# 727           flat  signature global orchard avenue   sector 93   0.36
#
#       price_per_sqft    area  \
# 20            7355.0   748.0
# 3147          8982.0  6123.0
# 2354          9550.0  1403.0
# 3594             NaN     NaN
# 727           6715.0   536.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 20                       Carpet area: 745 (69.21 sq.m.)        2         2
# 3147                 Built Up area: 5010 (465.44 sq.m.)        5         6
# 2354  Super Built up area 2355(218.79 sq.m.)Built Up...        4         5
# 3594  Plot area 350(292.64 sq.m.)Built Up area: 6500...        4         4
# 727                    Carpet area: 543.53 (50.5 sq.m.)        2         2
#
#      balcony                                 additionalRoom  floorNum  \
# 20         3                                  not available       4.0
# 3147      3+                        pooja room,servant room      19.0
# 2354      3+                                   servant room       7.0
# 3594      3+  pooja room,study room,servant room,store room       3.0
# 727        2                                  not available       6.0
#
#           facing     agePossession  \
# 20          East   0 to 1 Year Old
# 3147        East  5 to 10 Year Old
# 2354  South-East   1 to 5 Year Old
# 3594       North   0 to 1 Year Old
# 727        North   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 20    ['Sector 55-56 metro', 'Global city centre', '...
# 3147  ['Presidium School Gurgoan', 'Manav Rachna Sch...
# 2354  ['MG Road Metro Station', 'NeoSquare Shopping ...
# 3594  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 727   ['JMS Crosswalk Mall', 'Reliance Trends Newtow...
#
#                                          furnishDetails  \
# 20    ['1 Bed', '1 Fan', '1 Sofa', '1 Microwave', '1...
# 3147  ['1 Water Purifier', '12 Fan', '1 Exhaust Fan'...
# 2354  ['1 Fan', '1 Light', 'No AC', 'No Bed', 'No Ch...
# 3594                                                NaN
# 727                                                 NaN
#
#                                                features
# 20    ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3147  ['Water purifier', 'Security / Fire Alarm', 'P...
# 2354  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 3594  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 727   ['Power Back-up', 'Lift(s)', 'No open drainage...

# %%
df.to_csv('Gurgaon_properties.csv',index=False)

# %%
df.shape
# Out:
# (3619, 17)
