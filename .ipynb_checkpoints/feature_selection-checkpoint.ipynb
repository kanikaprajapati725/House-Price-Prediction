# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Gurgaon_properties_missing_value_imputation.csv')

# %%
df.shape
# Out:
# (3492, 18)

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6723.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#    bedRoom  bathroom balcony  floorNum       agePossession  built_up_area  \
# 0        2         2       1       4.0      Relatively New         1000.0
# 1        2         2       1       1.0        Old Property          722.0
# 2        2         2       3      12.0        New Property          661.0
# 3        2         2       2       2.0      Relatively New         1333.0
# 4        2         2       3       5.0  Under Construction         1217.0
#
#    study room  servant room  store room  pooja room  others furnishing_type  \
# 0           0             0           0           0       0     unfurnished
# 1           0             0           0           0       0   semifurnished
# 2           0             0           0           0       0     unfurnished
# 3           1             0           0           0       0     unfurnished
# 4           1             0           0           0       0     unfurnished
#
#    luxury_score
# 0            28
# 1            37
# 2            36
# 3            76
# 4             0

# %%
train_df = df.drop(columns=['society','price_per_sqft'])

# %%
sns.boxplot(x=df['luxury_score'])
# Out:
# <Axes: xlabel='luxury_score'>

# %%
def categorize_luxury(score):
    if 0 <= score < 50:
        return "basic"
    elif 50 <= score < 150:
        return "standard"
    elif 150 <= score <= 175:
        return "luxury"
    else:
        return None  # or "Undefined" or any other label for scores outside the defined bins

# %%
train_df['facilities']=train_df['luxury_score'].apply(categorize_luxury)

# %%
train_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  floorNum  \
# 0          flat    sector 7   0.45        2         2       1       4.0
# 1          flat    sector 3   0.50        2         2       1       1.0
# 2          flat  sohna road   0.40        2         2       3      12.0
# 3          flat   sector 61   1.47        2         2       2       2.0
# 4          flat   sector 92   0.70        2         2       3       5.0
#
#         agePossession  built_up_area  study room  servant room  store room  \
# 0      Relatively New         1000.0           0             0           0
# 1        Old Property          722.0           0             0           0
# 2        New Property          661.0           0             0           0
# 3      Relatively New         1333.0           1             0           0
# 4  Under Construction         1217.0           1             0           0
#
#    pooja room  others furnishing_type  luxury_score facilities
# 0           0       0     unfurnished            28      basic
# 1           0       0   semifurnished            37      basic
# 2           0       0     unfurnished            36      basic
# 3           0       0     unfurnished            76   standard
# 4           0       0     unfurnished             0      basic

# %%
sns.boxplot(x=df['floorNum'])
# Out:
# <Axes: xlabel='floorNum'>

# %%
def categorize_floor(floor):
    if 0 <= floor <= 2:
        return "Low Floor"
    elif 3 <= floor <= 10:
        return "Mid Floor"
    elif 11 <= floor <= 51:
        return "High Floor"
    else:
        return None  # or "Undefined" or any other label for floors outside the defined bins

# %%
train_df['floor_category'] = train_df['floorNum'].apply(categorize_floor)

# %%
train_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  floorNum  \
# 0          flat    sector 7   0.45        2         2       1       4.0
# 1          flat    sector 3   0.50        2         2       1       1.0
# 2          flat  sohna road   0.40        2         2       3      12.0
# 3          flat   sector 61   1.47        2         2       2       2.0
# 4          flat   sector 92   0.70        2         2       3       5.0
#
#         agePossession  built_up_area  study room  servant room  store room  \
# 0      Relatively New         1000.0           0             0           0
# 1        Old Property          722.0           0             0           0
# 2        New Property          661.0           0             0           0
# 3      Relatively New         1333.0           1             0           0
# 4  Under Construction         1217.0           1             0           0
#
#    pooja room  others furnishing_type  luxury_score facilities floor_category
# 0           0       0     unfurnished            28      basic      Mid Floor
# 1           0       0   semifurnished            37      basic      Low Floor
# 2           0       0     unfurnished            36      basic     High Floor
# 3           0       0     unfurnished            76   standard      Low Floor
# 4           0       0     unfurnished             0      basic      Mid Floor

# %%
train_df.drop(columns=['floorNum','luxury_score'],inplace=True)

# %%
train_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  \
# 0          flat    sector 7   0.45        2         2       1
# 1          flat    sector 3   0.50        2         2       1
# 2          flat  sohna road   0.40        2         2       3
# 3          flat   sector 61   1.47        2         2       2
# 4          flat   sector 92   0.70        2         2       3
#
#         agePossession  built_up_area  study room  servant room  store room  \
# 0      Relatively New         1000.0           0             0           0
# 1        Old Property          722.0           0             0           0
# 2        New Property          661.0           0             0           0
# 3      Relatively New         1333.0           1             0           0
# 4  Under Construction         1217.0           1             0           0
#
#    pooja room  others furnishing_type facilities floor_category
# 0           0       0     unfurnished      basic      Mid Floor
# 1           0       0   semifurnished      basic      Low Floor
# 2           0       0     unfurnished      basic     High Floor
# 3           0       0     unfurnished   standard      Low Floor
# 4           0       0     unfurnished      basic      Mid Floor

# %%
from sklearn.preprocessing import OrdinalEncoder

# Create a copy of the original data for label encoding
data_label_encoded = train_df.copy()

categorical_cols = train_df.select_dtypes(include=['object']).columns

# Apply label encoding to categorical columns
for col in categorical_cols:
    oe = OrdinalEncoder()
    data_label_encoded[col] = oe.fit_transform(data_label_encoded[[col]])
    print(oe.categories_)

# Splitting the dataset into training and testing sets
X_label = data_label_encoded.drop('price', axis=1)
y_label = data_label_encoded['price']
# Out:
# [array(['flat', 'house'], dtype=object)]
# [array(['dwarka expressway', 'gwal pahari', 'manesar', 'sector 1',
#        'sector 10', 'sector 102', 'sector 103', 'sector 104',
#        'sector 105', 'sector 106', 'sector 107', 'sector 108',
#        'sector 109', 'sector 11', 'sector 110', 'sector 111',
#        'sector 112', 'sector 113', 'sector 12', 'sector 13', 'sector 14',
#        'sector 17', 'sector 2', 'sector 21', 'sector 22', 'sector 23',
#        'sector 24', 'sector 25', 'sector 26', 'sector 27', 'sector 28',
#        'sector 3', 'sector 30', 'sector 31', 'sector 33', 'sector 36',
#        'sector 37', 'sector 38', 'sector 39', 'sector 4', 'sector 40',
#        'sector 41', 'sector 43', 'sector 45', 'sector 46', 'sector 47',
#        'sector 48', 'sector 49', 'sector 5', 'sector 50', 'sector 51',
#        'sector 52', 'sector 53', 'sector 54', 'sector 55', 'sector 56',
#        'sector 57', 'sector 58', 'sector 59', 'sector 6', 'sector 60',
#        'sector 61', 'sector 62', 'sector 63', 'sector 65', 'sector 66',
#        'sector 67', 'sector 68', 'sector 69', 'sector 7', 'sector 70',
#        'sector 71', 'sector 72', 'sector 74', 'sector 76', 'sector 77',
#        'sector 78', 'sector 79', 'sector 8', 'sector 80', 'sector 81',
#        'sector 82', 'sector 83', 'sector 84', 'sector 85', 'sector 86',
#        'sector 88', 'sector 88a', 'sector 89', 'sector 9', 'sector 90',
#        'sector 91', 'sector 92', 'sector 93', 'sector 95', 'sector 99',
#        'sohna road'], dtype=object)]
# [array(['0', '1', '2', '3', '3+'], dtype=object)]
# [array(['Moderately Old', 'New Property', 'Old Property', 'Relatively New',
#        'Under Construction'], dtype=object)]
# [array(['furnished', 'semifurnished', 'unfurnished'], dtype=object)]
# [array(['basic', 'luxury', 'standard'], dtype=object)]
# [array(['High Floor', 'Low Floor', 'Mid Floor', None], dtype=object)]

# %%
X_label
# Out:
#       property_type  sector  bedRoom  bathroom  balcony  agePossession  \
# 0               0.0    69.0        2         2      1.0            3.0
# 1               0.0    31.0        2         2      1.0            2.0
# 2               0.0    96.0        2         2      3.0            1.0
# 3               0.0    61.0        2         2      2.0            3.0
# 4               0.0    92.0        2         2      3.0            4.0
# ...             ...     ...      ...       ...      ...            ...
# 3487            1.0    56.0        3         3      3.0            0.0
# 3488            1.0    28.0        4         4      3.0            0.0
# 3489            1.0    27.0        3         2      3.0            2.0
# 3490            1.0    28.0        3         3      2.0            0.0
# 3491            1.0    28.0        3         3      3.0            2.0
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 0            1000.0           0             0           0           0       0
# 1             722.0           0             0           0           0       0
# 2             661.0           0             0           0           0       0
# 3            1333.0           1             0           0           0       0
# 4            1217.0           1             0           0           0       0
# ...             ...         ...           ...         ...         ...     ...
# 3487         1650.0           0             0           1           0       0
# 3488         1800.0           1             1           0           1       0
# 3489         1350.0           1             0           0           0       0
# 3490         1350.0           1             1           0           0       0
# 3491         8829.0           1             0           0           0       0
#
#       furnishing_type  facilities  floor_category
# 0                 2.0         0.0             2.0
# 1                 1.0         0.0             1.0
# 2                 2.0         0.0             0.0
# 3                 2.0         2.0             1.0
# 4                 2.0         0.0             2.0
# ...               ...         ...             ...
# 3487              1.0         2.0             1.0
# 3488              2.0         2.0             1.0
# 3489              2.0         0.0             1.0
# 3490              2.0         2.0             1.0
# 3491              2.0         2.0             1.0
#
# [3492 rows x 15 columns]

# %%
data_label_encoded['floor_category'].value_counts()
# Out:
# floor_category
# 2.0    1769
# 1.0     924
# 0.0     796
# 3.0       3
# Name: count, dtype: int64

# %% [markdown]
# ## 1.Correlation Analysis

# %%
sns.heatmap(data_label_encoded.corr())
# Out:
# <Axes: >

# %%
fi_df1 = data_label_encoded.corr()['price'].iloc[1:].to_frame().reset_index().rename(columns={'index':'feature','price':'corr_coeff'})
fi_df1
# Out:
#             feature  corr_coeff
# 0            sector   -0.210335
# 1             price    1.000000
# 2           bedRoom    0.588807
# 3          bathroom    0.604276
# 4           balcony    0.266362
# 5     agePossession   -0.134225
# 6     built_up_area    0.745364
# 7        study room    0.243441
# 8      servant room    0.393822
# 9        store room    0.304817
# 10       pooja room    0.322355
# 11           others   -0.011378
# 12  furnishing_type   -0.225760
# 13       facilities    0.053350
# 14   floor_category    0.039455

# %% [markdown]
# ## 2.random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# Train a Random Forest regressor on label encoded data
rf_label = RandomForestRegressor(n_estimators=100, random_state=42)
rf_label.fit(X_label, y_label)

# Extract feature importance scores for label encoded data
fi_df2 = pd.DataFrame({
    'feature': X_label.columns,
    'rf_importance': rf_label.feature_importances_
}).sort_values(by='rf_importance', ascending=False)

fi_df2
# Out:
#             feature  rf_importance
# 6     built_up_area       0.644072
# 0     property_type       0.114154
# 1            sector       0.098903
# 2           bedRoom       0.025851
# 3          bathroom       0.024387
# 8      servant room       0.019620
# 5     agePossession       0.013271
# 4           balcony       0.012701
# 12  furnishing_type       0.009797
# 7        study room       0.008617
# 13       facilities       0.007797
# 10       pooja room       0.006629
# 14   floor_category       0.006124
# 9        store room       0.005501
# 11           others       0.002577

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Train a Random Forest regressor on label encoded data
gb_label = GradientBoostingRegressor()
gb_label.fit(X_label, y_label)

# Extract feature importance scores for label encoded data
fi_df3 = pd.DataFrame({
    'feature': X_label.columns,
    'gb_importance': gb_label.feature_importances_
}).sort_values(by='gb_importance', ascending=False)

fi_df3
# Out:
#             feature  gb_importance
# 6     built_up_area       0.684289
# 0     property_type       0.106741
# 1            sector       0.093457
# 2           bedRoom       0.036681
# 3          bathroom       0.033663
# 8      servant room       0.021946
# 9        store room       0.009285
# 12  furnishing_type       0.004678
# 7        study room       0.003978
# 5     agePossession       0.002743
# 4           balcony       0.001506
# 13       facilities       0.000466
# 14   floor_category       0.000433
# 11           others       0.000097
# 10       pooja room       0.000037

# %%
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split

X_train_label, X_test_label, y_train_label, y_test_label = train_test_split(X_label, y_label, test_size=0.2, random_state=42)

# Train a Random Forest regressor on label encoded data
rf_label = RandomForestRegressor(n_estimators=100, random_state=42)
rf_label.fit(X_train_label, y_train_label)

# Calculate Permutation Importance
perm_importance = permutation_importance(rf_label, X_test_label, y_test_label, n_repeats=30)
# Organize results into a DataFrame
fi_df4 = pd.DataFrame({
    'feature': X_label.columns,
    'permutation_importance': perm_importance.importances_mean
}).sort_values(by='permutation_importance', ascending=False)

fi_df4
# Out:
#             feature  permutation_importance
# 6     built_up_area                0.770453
# 0     property_type                0.194049
# 1            sector                0.140447
# 3          bathroom                0.019125
# 2           bedRoom                0.018917
# 8      servant room                0.014476
# 4           balcony                0.010800
# 12  furnishing_type                0.003924
# 9        store room                0.002884
# 5     agePossession                0.002858
# 10       pooja room                0.002093
# 7        study room                0.001134
# 11           others                0.000749
# 14   floor_category                0.000201
# 13       facilities               -0.000508

# %% [markdown]
# ## LASSO

# %%
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_label)

# Train a LASSO regression model
# We'll use a relatively small value for alpha (the regularization strength) for demonstration purposes
lasso = Lasso(alpha=0.01, random_state=42)
lasso.fit(X_scaled, y_label)

# Extract coefficients
fi_df5 = pd.DataFrame({
    'feature': X_label.columns,
    'lasso_coeff': lasso.coef_
}).sort_values(by='lasso_coeff', ascending=False)

fi_df5
# Out:
#             feature  lasso_coeff
# 6     built_up_area     1.499260
# 0     property_type     0.736455
# 3          bathroom     0.249789
# 9        store room     0.193177
# 7        study room     0.173586
# 8      servant room     0.155045
# 10       pooja room     0.076087
# 13       facilities     0.037022
# 2           bedRoom     0.017287
# 14   floor_category    -0.000000
# 11           others    -0.013482
# 5     agePossession    -0.016256
# 4           balcony    -0.043833
# 1            sector    -0.055293
# 12  furnishing_type    -0.162687

# %%
from sklearn.feature_selection import RFE

# Initialize the base estimator
estimator = RandomForestRegressor()

# Apply RFE on the label-encoded and standardized training data
selector_label = RFE(estimator, n_features_to_select=X_label.shape[1], step=1)
selector_label = selector_label.fit(X_label, y_label)

# Get the selected features based on RFE
selected_features = X_label.columns[selector_label.support_]

# Extract the coefficients for the selected features from the underlying linear regression model
selected_coefficients = selector_label.estimator_.feature_importances_

# Organize the results into a DataFrame
fi_df6 = pd.DataFrame({
    'feature': selected_features,
    'rfe_score': selected_coefficients
}).sort_values(by='rfe_score', ascending=False)

fi_df6
# Out:
#             feature  rfe_score
# 6     built_up_area   0.645947
# 0     property_type   0.110861
# 1            sector   0.097511
# 2           bedRoom   0.025960
# 3          bathroom   0.025518
# 8      servant room   0.017814
# 5     agePossession   0.013489
# 4           balcony   0.013321
# 12  furnishing_type   0.010698
# 7        study room   0.008232
# 13       facilities   0.008158
# 9        store room   0.007509
# 14   floor_category   0.006503
# 10       pooja room   0.005664
# 11           others   0.002817

# %%
from sklearn.linear_model import LinearRegression

# Train a linear regression models
lin_reg = LinearRegression()
lin_reg.fit(X_scaled, y_label)

# Extract coefficients
fi_df7 = pd.DataFrame({
    'feature': X_label.columns,
    'reg_coeffs': lin_reg.coef_
}).sort_values(by='reg_coeffs', ascending=False)

fi_df7
# Out:
#             feature  reg_coeffs
# 6     built_up_area    1.502005
# 0     property_type    0.734977
# 3          bathroom    0.256937
# 9        store room    0.196952
# 7        study room    0.182033
# 8      servant room    0.162363
# 10       pooja room    0.078591
# 13       facilities    0.046810
# 2           bedRoom    0.020035
# 14   floor_category   -0.009167
# 11           others   -0.020557
# 5     agePossession   -0.024788
# 1            sector   -0.064303
# 4           balcony   -0.067734
# 12  furnishing_type   -0.170432

# %%
final_fi_df = fi_df1.merge(fi_df2,on='feature').merge(fi_df3,on='feature').merge(fi_df4,on='feature').merge(fi_df5,on='feature').merge(fi_df6,on='feature').merge(fi_df7,on='feature').set_index('feature')

# %%
final_fi_df
# Out:
#                  corr_coeff  rf_importance  gb_importance  \
# feature
# sector            -0.210335       0.098903       0.093457
# bedRoom            0.588807       0.025851       0.036681
# bathroom           0.604276       0.024387       0.033663
# balcony            0.266362       0.012701       0.001506
# agePossession     -0.134225       0.013271       0.002743
# built_up_area      0.745364       0.644072       0.684289
# study room         0.243441       0.008617       0.003978
# servant room       0.393822       0.019620       0.021946
# store room         0.304817       0.005501       0.009285
# pooja room         0.322355       0.006629       0.000037
# others            -0.011378       0.002577       0.000097
# furnishing_type   -0.225760       0.009797       0.004678
# facilities         0.053350       0.007797       0.000466
# floor_category     0.039455       0.006124       0.000433
#
#                  permutation_importance  lasso_coeff  rfe_score  reg_coeffs
# feature
# sector                         0.140447    -0.055293   0.097511   -0.064303
# bedRoom                        0.018917     0.017287   0.025960    0.020035
# bathroom                       0.019125     0.249789   0.025518    0.256937
# balcony                        0.010800    -0.043833   0.013321   -0.067734
# agePossession                  0.002858    -0.016256   0.013489   -0.024788
# built_up_area                  0.770453     1.499260   0.645947    1.502005
# study room                     0.001134     0.173586   0.008232    0.182033
# servant room                   0.014476     0.155045   0.017814    0.162363
# store room                     0.002884     0.193177   0.007509    0.196952
# pooja room                     0.002093     0.076087   0.005664    0.078591
# others                         0.000749    -0.013482   0.002817   -0.020557
# furnishing_type                0.003924    -0.162687   0.010698   -0.170432
# facilities                    -0.000508     0.037022   0.008158    0.046810
# floor_category                 0.000201    -0.000000   0.006503   -0.009167

# %%
final_fi_df = final_fi_df.divide(final_fi_df.sum(axis=0), axis=1)

# %%
final_fi_df[['rf_importance','gb_importance','permutation_importance','rfe_score']].mean(axis=1).sort_values(ascending=False)
# Out:
# feature
# built_up_area      0.749945
# sector             0.117040
# bedRoom            0.029650
# bathroom           0.028320
# servant room       0.020352
# balcony            0.010485
# agePossession      0.009029
# furnishing_type    0.008075
# store room         0.006992
# study room         0.006147
# facilities         0.004496
# pooja room         0.004003
# floor_category     0.003729
# others             0.001736
# dtype: float64

# %%
# with all the cols
from sklearn.model_selection import cross_val_score

rf = RandomForestRegressor(n_estimators=100, random_state=42)

scores = cross_val_score(rf, X_label, y_label, cv=5, scoring='r2')

# %%
scores.mean()
# Out:
# 0.7288462876315854

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=42)

scores = cross_val_score(rf, X_label.drop(columns=['pooja room', 'study room', 'others']), y_label, cv=5, scoring='r2')

# %%
scores.mean()
# Out:
# 0.727155696885856

# %%
export_df = X_label.drop(columns=['pooja room', 'study room', 'others'])
export_df['price'] = y_label

# %%
export_df.to_csv('gurgaon_properties_post_feature_selection.csv', index=False)

# %%
export_df
# Out:
#       property_type  sector  bedRoom  bathroom  balcony  agePossession  \
# 0               0.0    69.0        2         2      1.0            3.0
# 1               0.0    31.0        2         2      1.0            2.0
# 2               0.0    96.0        2         2      3.0            1.0
# 3               0.0    61.0        2         2      2.0            3.0
# 4               0.0    92.0        2         2      3.0            4.0
# ...             ...     ...      ...       ...      ...            ...
# 3487            1.0    56.0        3         3      3.0            0.0
# 3488            1.0    28.0        4         4      3.0            0.0
# 3489            1.0    27.0        3         2      3.0            2.0
# 3490            1.0    28.0        3         3      2.0            0.0
# 3491            1.0    28.0        3         3      3.0            2.0
#
#       built_up_area  servant room  store room  furnishing_type  facilities  \
# 0            1000.0             0           0              2.0         0.0
# 1             722.0             0           0              1.0         0.0
# 2             661.0             0           0              2.0         0.0
# 3            1333.0             0           0              2.0         2.0
# 4            1217.0             0           0              2.0         0.0
# ...             ...           ...         ...              ...         ...
# 3487         1650.0             0           1              1.0         2.0
# 3488         1800.0             1           0              2.0         2.0
# 3489         1350.0             0           0              2.0         0.0
# 3490         1350.0             1           0              2.0         2.0
# 3491         8829.0             0           0              2.0         2.0
#
#       floor_category  price
# 0                2.0   0.45
# 1                1.0   0.50
# 2                0.0   0.40
# 3                1.0   1.47
# 4                2.0   0.70
# ...              ...    ...
# 3487             1.0   4.75
# 3488             1.0   5.50
# 3489             1.0   4.25
# 3490             1.0   4.50
# 3491             1.0   3.25
#
# [3492 rows x 13 columns]

# %% [markdown]
# # Baseline Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('gurgaon_properties_post_feature_selection.csv')

# %%
df.head()
# Out:
#    property_type  sector  bedRoom  bathroom  balcony  agePossession  \
# 0            0.0    69.0        2         2      1.0            3.0
# 1            0.0    31.0        2         2      1.0            2.0
# 2            0.0    96.0        2         2      3.0            1.0
# 3            0.0    61.0        2         2      2.0            3.0
# 4            0.0    92.0        2         2      3.0            4.0
#
#    built_up_area  servant room  store room  furnishing_type  facilities  \
# 0         1000.0             0           0              2.0         0.0
# 1          722.0             0           0              1.0         0.0
# 2          661.0             0           0              2.0         0.0
# 3         1333.0             0           0              2.0         2.0
# 4         1217.0             0           0              2.0         0.0
#
#    floor_category  price
# 0             2.0   0.45
# 1             1.0   0.50
# 2             0.0   0.40
# 3             1.0   1.47
# 4             2.0   0.70

# %%
pip install xgboost

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[87], line 8
#       6 from sklearn.svm import SVR
#       7 from sklearn.ensemble import RandomForestRegressor
# ----> 8 from xgboost import XGBRegressor
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
columns_to_encode = ['sector', 'balcony', 'agePossession', 'furnishing_type', 'facilities', 'floor_category']

# %%
sns.distplot(y)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_2984\476133659.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y)
# <Axes: xlabel='price', ylabel='Density'>

# %%
y_transformed = np.log1p(y)

# %%
sns.distplot(y_transformed)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_2984\1376935547.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_transformed)
# <Axes: xlabel='price', ylabel='Density'>

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['property_type','bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), columns_to_encode)
    ],
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
# Out:
# C:\Users\manoj\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
scores.mean()
# Out:
# 0.8558592313525955

# %%
scores.std()
# Out:
# 0.020963946898245676
