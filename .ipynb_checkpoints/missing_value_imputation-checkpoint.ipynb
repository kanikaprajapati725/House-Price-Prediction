# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Gurgaon_properties_outlier_treated.csv')

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6723.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
#    floorNum facing       agePossession  super_built_up_area  built_up_area  \
# 0       4.0   West      Relatively New                  NaN            NaN
# 1       1.0   West        Old Property                  NaN            NaN
# 2      12.0    NaN        New Property                  NaN            NaN
# 3       2.0    NaN      Relatively New                  NaN            NaN
# 4       5.0    NaN  Under Construction               1345.0            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0        900.0           0             0           0           0       0
# 1        650.0           0             0           0           0       0
# 2        595.0           0             0           0           0       0
# 3       1200.0           1             0           0           0       0
# 4          NaN           1             0           0           0       0
#
#   furnishing_type  luxury_score  area_room_ratio
# 0     unfurnished            28            450.0
# 1   semifurnished            37            325.0
# 2     unfurnished            36            297.5
# 3     unfurnished            76            600.0
# 4     unfurnished             0            672.5

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                  984
# agePossession             0
# super_built_up_area    1625
# built_up_area          1949
# carpet_area            1674
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %% [markdown]
# ## bulit_up_area

# %%
sns.scatterplot(x=df['built_up_area'],y=df['super_built_up_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(x=df['built_up_area'],y=df['carpet_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='carpet_area'>

# %%
((df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())).sum()
# Out:
# 0

# %%
all_present_df = df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]

# %%
all_present_df.shape
# Out:
# (530, 24)

# %%
all_present_df.shape
# Out:
# (530, 24)

# %%
super_to_built_up_ratio = (all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()

# %%
carpet_to_built_up_ratio = (all_present_df['carpet_area']/all_present_df['built_up_area']).median()

# %%
print(super_to_built_up_ratio, carpet_to_built_up_ratio)
# Out:
# 1.1052289815447711 0.900140056022409

# %%
# both present built up null
sbc_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
sbc_df.head()
# Out:
#    property_type                 society      sector  price  price_per_sqft  \
# 30          flat             bhawna cghs   sector 43   3.25         10156.0
# 35          flat       chintels paradiso  sector 109   1.80          8867.0
# 36          flat  breez global hill view  sohna road   0.30          5405.0
# 56          flat  silverglades the melia  sohna road   1.01          6999.0
# 58          flat      umang winter hills   sector 77   0.99          7857.0
#
#       area                                       areaWithType  bedRoom  \
# 30  3200.0  Super Built up area 3200(297.29 sq.m.)Carpet a...        4
# 35  2030.0  Super Built up area 2030(188.59 sq.m.)Carpet a...        3
# 36   555.0  Super Built up area 655(60.85 sq.m.)Carpet are...        2
# 56  1443.0  Super Built up area 1450(134.71 sq.m.)Carpet a...        2
# 58  1260.0  Super Built up area 1260(117.06 sq.m.)Carpet a...        2
#
#     bathroom balcony  floorNum      facing   agePossession  \
# 30         4      3+      12.0         NaN  Moderately Old
# 35         3       2       0.0        East  Moderately Old
# 36         2       2       6.0  North-East    New Property
# 56         2       3      12.0         NaN  Relatively New
# 58         2       2       1.0       North  Relatively New
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 30               3200.0            NaN       3000.0           0             0
# 35               2030.0            NaN       1785.0           0             1
# 36                655.0            NaN        555.0           0             0
# 56               1450.0            NaN        950.0           1             0
# 58               1260.0            NaN       1000.0           0             0
#
#     store room  pooja room  others furnishing_type  luxury_score  \
# 30           0           1       0   semifurnished           119
# 35           0           0       0     unfurnished            83
# 36           0           0       0     unfurnished           109
# 56           0           0       0     unfurnished            80
# 58           0           0       0     unfurnished            97
#
#     area_room_ratio
# 30       800.000000
# 35       676.666667
# 36       277.500000
# 56       721.500000
# 58       630.000000

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) +(sbc_df['carpet_area']/0.9))/2),inplace=True)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_3384\1533986712.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) +(sbc_df['carpet_area']/0.9))/2),inplace=True)
# C:\Users\manoj\AppData\Local\Temp\ipykernel_3384\1533986712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) +(sbc_df['carpet_area']/0.9))/2),inplace=True)

# %%
df.update(sbc_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                  984
# agePossession             0
# super_built_up_area    1625
# built_up_area          1528
# carpet_area            1674
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# sb present c is null built up null
sb_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]

# %%
sb_df.head()
# Out:
#    property_type                     society             sector  price  \
# 4           flat            parkwood westend          sector 92   0.70
# 6           flat                  the cocoon  dwarka expressway   2.00
# 13          flat                      godrej          sector 33   0.95
# 14          flat        shree vardhman flora          sector 90   0.70
# 18          flat  central park flower valley          sector 33   2.20
#
#     price_per_sqft    area                            areaWithType  bedRoom  \
# 4           5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)        2
# 6          13333.0  1500.0  Super Built up area 1500(139.35 sq.m.)        3
# 13          6859.0  1385.0  Super Built up area 1385(128.67 sq.m.)        2
# 14          5385.0  1300.0  Super Built up area 1300(120.77 sq.m.)        2
# 18         10476.0  2100.0   Super Built up area 2100(195.1 sq.m.)        3
#
#     bathroom balcony  floorNum      facing       agePossession  \
# 4          2       3       5.0         NaN  Under Construction
# 6          3       3       5.0         NaN        New Property
# 13         2      3+       3.0  South-East  Under Construction
# 14         2       3      13.0         NaN        New Property
# 18         3       3      12.0  North-East        New Property
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 4                1345.0            NaN          NaN           1             0
# 6                1500.0            NaN          NaN           0             0
# 13               1385.0            NaN          NaN           0             0
# 14               1300.0            NaN          NaN           1             0
# 18               2100.0            NaN          NaN           0             1
#
#     store room  pooja room  others furnishing_type  luxury_score  \
# 4            0           0       0     unfurnished             0
# 6            0           0       0     unfurnished             0
# 13           0           0       0     unfurnished             0
# 14           0           0       0     unfurnished            15
# 18           0           0       0   semifurnished            49
#
#     area_room_ratio
# 4             672.5
# 6             500.0
# 13            692.5
# 14            650.0
# 18            700.0

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_3384\1714170073.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# C:\Users\manoj\AppData\Local\Temp\ipykernel_3384\1714170073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)

# %%
df.update(sb_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                  984
# agePossession             0
# super_built_up_area    1625
# built_up_area           658
# carpet_area            1674
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# sb null c is present built up null
c_df = df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
c_df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6723.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 7          flat             ats triumph  sector 104   1.80          7860.0
#
#      area                      areaWithType  bedRoom  bathroom balcony  \
# 0   900.0    Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0    Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0    Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0  Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 7  2290.0  Carpet area: 2290 (212.75 sq.m.)        3         4       3
#
#    floorNum facing   agePossession  super_built_up_area  built_up_area  \
# 0       4.0   West  Relatively New                  NaN            NaN
# 1       1.0   West    Old Property                  NaN            NaN
# 2      12.0    NaN    New Property                  NaN            NaN
# 3       2.0    NaN  Relatively New                  NaN            NaN
# 7      14.0    NaN    New Property                  NaN            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0        900.0           0             0           0           0       0
# 1        650.0           0             0           0           0       0
# 2        595.0           0             0           0           0       0
# 3       1200.0           1             0           0           0       0
# 7       2290.0           0             0           0           0       0
#
#   furnishing_type  luxury_score  area_room_ratio
# 0     unfurnished            28       450.000000
# 1   semifurnished            37       325.000000
# 2     unfurnished            36       297.500000
# 3     unfurnished            76       600.000000
# 7     unfurnished            60       763.333333

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_3384\2136919732.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# C:\Users\manoj\AppData\Local\Temp\ipykernel_3384\2136919732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)

# %%
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                  984
# agePossession             0
# super_built_up_area    1625
# built_up_area             0
# carpet_area            1674
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
anamoly_df = df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]

# %%
anamoly_df.sample(5)
# Out:
#       price    area  built_up_area
# 2037   3.30  2150.0         1640.0
# 3341   3.49  1728.0         1728.0
# 3428   4.50  1350.0         1350.0
# 1362   2.70  2576.0         1891.0
# 3385   7.10  2259.0          240.0

# %%
anamoly_df['built_up_area'] = anamoly_df['area']

# %%
df.update(anamoly_df)

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6723.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#    bedRoom  bathroom balcony  floorNum facing       agePossession  \
# 0        2         2       1       4.0   West      Relatively New
# 1        2         2       1       1.0   West        Old Property
# 2        2         2       3      12.0    NaN        New Property
# 3        2         2       2       2.0    NaN      Relatively New
# 4        2         2       3       5.0    NaN  Under Construction
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# 0         1000.0           0             0           0           0       0
# 1          722.0           0             0           0           0       0
# 2          661.0           0             0           0           0       0
# 3         1333.0           1             0           0           0       0
# 4         1217.0           1             0           0           0       0
#
#   furnishing_type  luxury_score
# 0     unfurnished            28
# 1   semifurnished            37
# 2     unfurnished            36
# 3     unfurnished            76
# 4     unfurnished             0

# %%
df.shape
# Out:
# (3494, 19)

# %%
df.isnull().sum()
# Out:
# property_type        0
# society              1
# sector               0
# price                0
# price_per_sqft       0
# bedRoom              0
# bathroom             0
# balcony              0
# floorNum            17
# facing             984
# agePossession        0
# built_up_area        0
# study room           0
# servant room         0
# store room           0
# pooja room           0
# others               0
# furnishing_type      0
# luxury_score         0
# dtype: int64

# %% [markdown]
# ## floorNum

# %%
df[df['floorNum'].isnull()]
# Out:
#      property_type                  society             sector  price  \
# 167           flat       experion heartsong  dwarka expressway   1.08
# 2557          flat                      NaN          sector 78   0.60
# 2800         house       vipul tatvam villa          sector 48   8.50
# 2819         house              independent           sector 2   5.60
# 2888         house              independent          sector 24   1.45
# 2916         house              independent           sector 3   1.50
# 2928         house              independent           sector 4   4.12
# 2973         house              independent           sector 4   0.65
# 2986         house  ansal sushant lok plots          sector 43   3.30
# 3100         house               jacob pura          sector 12   0.35
# 3121         house              independent          sector 25  13.00
# 3160         house              independent           sector 7   6.50
# 3285         house     dlf new town heights          sector 86   2.47
# 3302         house       vipul tatvam villa          sector 48   8.50
# 3307         house        ansal sushant lok          sector 43  10.50
# 3310         house              independent          sector 26   4.60
# 3422         house       emaar mgf marbella          sector 66   9.00
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 167           6150.0        3         3       0       NaN         NaN
# 2557          3692.0        2         2       0       NaN         NaN
# 2800         26235.0        4         4       2       NaN        East
# 2819         17284.0        8         6      3+       NaN  South-West
# 2888          2984.0        3         3       1       NaN         NaN
# 2916         10288.0        3         3       0       NaN         NaN
# 2928          8889.0        2         1      3+       NaN         NaN
# 2973         11111.0        4         2       2       NaN         NaN
# 2986         26570.0        1         1       0       NaN         NaN
# 3100          9722.0        2         1       0       NaN         NaN
# 3121         45710.0        6         8      3+       NaN         NaN
# 3160         15046.0        3         2      3+       NaN         NaN
# 3285          7719.0        4         4      3+       NaN        West
# 3302         26235.0        4         4       1       NaN         NaN
# 3307         27911.0        4         4       2       NaN  North-East
# 3310         12198.0        4         4      3+       NaN         NaN
# 3422         21251.0        4         4      3+       NaN  South-West
#
#            agePossession  built_up_area  study room  servant room  store room  \
# 167   Under Construction         1758.0           0             0           0
# 2557  Under Construction         1625.0           0             0           0
# 2800      Moderately Old         3240.0           0             1           1
# 2819      Moderately Old         3240.0           1             1           1
# 2888        Old Property          540.0           0             0           0
# 2916        Old Property          210.0           0             0           0
# 2928      Moderately Old         4635.0           0             0           0
# 2973      Moderately Old          585.0           0             0           0
# 2986  Under Construction         1242.0           0             0           0
# 3100        Old Property          360.0           0             0           0
# 3121      Relatively New         2844.0           1             1           1
# 3160        Old Property         4320.0           0             0           0
# 3285      Moderately Old         2800.0           0             1           0
# 3302      Relatively New         3240.0           0             0           0
# 3307        Old Property         3762.0           0             1           0
# 3310        Old Property         3771.0           0             0           0
# 3422      Relatively New         5200.0           0             1           1
#
#       pooja room  others furnishing_type  luxury_score
# 167            0       0     unfurnished             0
# 2557           0       0     unfurnished             0
# 2800           1       0     unfurnished            88
# 2819           1       0     unfurnished             0
# 2888           0       0     unfurnished             9
# 2916           0       0     unfurnished             0
# 2928           0       0     unfurnished             0
# 2973           0       0     unfurnished             0
# 2986           0       0     unfurnished             0
# 3100           0       0     unfurnished             0
# 3121           1       0       furnished             0
# 3160           0       0     unfurnished             9
# 3285           1       0   semifurnished           130
# 3302           0       0     unfurnished            21
# 3307           0       0     unfurnished            59
# 3310           0       0     unfurnished            28
# 3422           1       0   semifurnished           114

# %%
df[df['property_type'] == 'house']['floorNum'].median()
# Out:
# 2.0

# %%
df['floorNum'].fillna(2.0,inplace=True)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_3384\15612474.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['floorNum'].fillna(2.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type        0
# society              1
# sector               0
# price                0
# price_per_sqft       0
# bedRoom              0
# bathroom             0
# balcony              0
# floorNum             0
# facing             984
# agePossession        0
# built_up_area        0
# study room           0
# servant room         0
# store room           0
# pooja room           0
# others               0
# furnishing_type      0
# luxury_score         0
# dtype: int64

# %% [markdown]
# ## facing

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.drop(columns=['facing'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                  society      sector  price  \
# 2799         house              independent   sector 48   8.40
# 3088         house        vatika india next   sector 82   6.50
# 2635          flat                  my home  sector 110   0.22
# 3082         house       bhim nagar society    sector 6   0.40
# 2400          flat  sare green parc phase 3   sector 92   0.95
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 2799         25926.0        4         4       3       2.0    Old Property
# 3088         20062.0        4         3       0       2.0       Undefined
# 2635          4400.0        2         2       1       1.0    New Property
# 3082          2500.0        4         2       2       1.0       Undefined
# 2400          4857.0        4         3       3       4.0  Moderately Old
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 2799         3240.0           0             1           0           1       0
# 3088         3240.0           0             0           0           0       0
# 2635          556.0           0             0           0           0       0
# 3082         1600.0           0             0           0           0       0
# 2400         1770.0           0             0           0           0       0
#
#      furnishing_type  luxury_score
# 2799   semifurnished            15
# 3088     unfurnished             0
# 2635   semifurnished             0
# 3082     unfurnished             0
# 2400     unfurnished            67

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df[df['society'].isnull()]
# Out:
#      property_type society     sector  price  price_per_sqft  bedRoom  \
# 2557          flat     NaN  sector 78    0.6          3692.0        2
#
#       bathroom balcony  floorNum       agePossession  built_up_area  \
# 2557         2       0       2.0  Under Construction         1625.0
#
#       study room  servant room  store room  pooja room  others  \
# 2557           0             0           0           0       0
#
#      furnishing_type  luxury_score
# 2557     unfurnished             0

# %%
df.drop(index=[2557],inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %% [markdown]
# ## agePossession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1692
# New Property           573
# Moderately Old         538
# Old Property           282
# Undefined              280
# Under Construction     128
# Name: count, dtype: int64

# %%
df[df['agePossession'] == 'Undefined']
# Out:
#      property_type                         society      sector  price  \
# 5             flat  signature global infinity mall   sector 36   0.41
# 15            flat                      sobha city  sector 108   3.95
# 16            flat                    senate court   sector 62   0.90
# 24            flat                     the serenas   sector 36   0.42
# 25            flat                  m3m golfestate   sector 65   6.15
# ...            ...                             ...         ...    ...
# 3149         house                     independent  sector 108   1.34
# 3151         house                     independent   sector 39   0.34
# 3152         house                     independent  sector 105   9.90
# 3153         house                     independent   sector 43   2.15
# 3156         house         project mianwali colony   sector 12   2.00
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum agePossession  \
# 5             6269.0        2         2       3       3.0     Undefined
# 15           16859.0        4         5       3      25.0     Undefined
# 16           14085.0        1         1       0       0.0     Undefined
# 24            7910.0        2         2       1       3.0     Undefined
# 25           18331.0        3         4       2      20.0     Undefined
# ...              ...      ...       ...     ...       ...           ...
# 3149          5000.0        1         1       0       1.0     Undefined
# 3151          7556.0        1         1       1       1.0     Undefined
# 3152         49500.0        2         2       2       3.0     Undefined
# 3153         13030.0        1         1       0       1.0     Undefined
# 3156         14815.0        5         5       2       3.0     Undefined
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 5             654.0           0             0           0           0       0
# 15           2343.0           0             0           0           0       0
# 16            639.0           0             0           0           0       0
# 24            590.0           0             0           0           0       0
# 25           3355.0           0             0           0           0       0
# ...             ...         ...           ...         ...         ...     ...
# 3149         2680.0           0             0           0           0       0
# 3151          450.0           0             0           0           0       0
# 3152         2000.0           0             0           0           0       0
# 3153         1650.0           0             0           0           0       0
# 3156         1350.0           0             0           0           0       0
#
#      furnishing_type  luxury_score
# 5        unfurnished             0
# 15       unfurnished            59
# 16       unfurnished             0
# 24       unfurnished             0
# 25       unfurnished            34
# ...              ...           ...
# 3149     unfurnished             0
# 3151     unfurnished             0
# 3152     unfurnished             0
# 3153     unfurnished             0
# 3156     unfurnished             0
#
# [280 rows x 18 columns]

# %%
def mode_based_imputation(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector']) & (df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1814
# New Property           612
# Moderately Old         576
# Old Property           312
# Under Construction     132
# Undefined               47
# Name: count, dtype: int64

# %%
def mode_based_imputation2(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1820
# New Property           612
# Moderately Old         580
# Old Property           315
# Under Construction     132
# Undefined               34
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation3,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1822
# New Property           612
# Moderately Old         612
# Old Property           315
# Under Construction     132
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.to_csv('Gurgaon_properties_missing_value_imputation.csv',index=False)

# %%
df.shape
# Out:
# (3493, 18)

# %%
df=pd.read_csv('Gurgaon_properties_missing_value_imputation.csv')

# %%
df[df['built_up_area'] < 100]
# Out:
#      property_type               society      sector  price  price_per_sqft  \
# 29            flat   ompee k s residency  sector 110   1.60          2993.0
# 100           flat           godrej aria   sector 79   1.10         11482.0
# 280           flat            godrej air   sector 85   1.05         10606.0
# 1877          flat    godrej nature plus   sector 33   1.31         15976.0
# 2002          flat    godrej nature plus   sector 33   1.20         14371.0
# 2038          flat  housing board colony   sector 51   0.30          4630.0
# 2204          flat                godrej   sector 79   1.47         16261.0
# 2213          flat    godrej nature plus   sector 33   1.20         13363.0
# 2461          flat         godrej summit  sector 104   0.82          9856.0
# 2571          flat    godrej nature plus   sector 33   1.08         13123.0
# 2867         house           independent    sector 4   0.58          9619.0
# 2868         house           independent    sector 4   0.65         10317.0
# 2869         house           independent    sector 4   0.61         11111.0
# 2870         house           independent    sector 4   0.67          9795.0
# 2936         house           independent    sector 9   0.22          7407.0
# 2941         house           independent  sohna road   0.07          2527.0
# 3008         house           independent    sector 4   0.60         11696.0
# 3072         house           independent  sector 105   0.55         10913.0
# 3077         house           independent  sector 105   0.38          8444.0
# 3143         house           independent   sector 43   1.90          3909.0
# 3145         house      suncity township   sector 54   2.00          3440.0
# 3158         house           independent    sector 4   0.55          6815.0
# 3197         house           independent   sector 55   1.45         26852.0
# 3218         house    eros rosewood city   sector 49   1.60          3500.0
# 3250         house           independent    sector 4   0.47         10609.0
# 3377         house           independent   sector 46   2.25          2723.0
#
#       bedRoom  bathroom balcony  floorNum       agePossession  built_up_area  \
# 29          2         2       2       1.0      Relatively New           73.0
# 100         2         2       3       9.0        New Property           81.0
# 280         2         2       1      15.0      Relatively New           97.0
# 1877        2         2       2       4.0  Under Construction           85.0
# 2002        2         2       3       1.0        New Property           86.0
# 2038        1         1       0       0.0      Moderately Old           80.0
# 2204        2         2       3       9.0        New Property           93.0
# 2213        2         2       0      11.0  Under Construction           85.0
# 2461        2         2       3      12.0      Relatively New           86.0
# 2571        2         2       3       8.0      Relatively New           85.0
# 2867        2         2       1       2.0      Moderately Old           67.0
# 2868        1         1       1       1.0      Moderately Old           70.0
# 2869        2         2       2       2.0      Moderately Old           61.0
# 2870        3         3       2       2.0      Relatively New           76.0
# 2936        2         2       2       1.0        Old Property           37.0
# 2941        1         1       0       1.0      Relatively New           33.0
# 3008        3         3       1       2.0        Old Property           57.0
# 3072        2         4       0       2.0      Moderately Old           56.0
# 3077        2         2       2       1.0      Moderately Old           56.0
# 3143        3         3      3+       3.0        Old Property           60.0
# 3145        9         9       3      11.0      Relatively New           60.0
# 3158        2         1       1       1.0      Moderately Old           75.0
# 3197        1         4      3+       4.0      Relatively New           60.0
# 3218        4         4       3       4.0        New Property           60.0
# 3250        2         2       1       2.0        New Property           50.0
# 3377        4         3       3       3.0      Relatively New           90.0
#
#       study room  servant room  store room  pooja room  others  \
# 29             0             0           0           0       0
# 100            0             0           0           0       0
# 280            0             0           0           0       0
# 1877           0             0           0           0       0
# 2002           0             0           0           0       0
# 2038           1             0           0           0       0
# 2204           1             0           0           0       0
# 2213           0             0           0           0       0
# 2461           1             0           0           0       0
# 2571           0             0           0           0       0
# 2867           0             0           0           1       1
# 2868           0             0           0           0       1
# 2869           0             0           0           0       1
# 2870           0             0           0           0       1
# 2936           0             0           0           0       0
# 2941           0             0           0           0       0
# 3008           0             0           0           0       1
# 3072           0             0           0           0       0
# 3077           0             0           0           0       0
# 3143           0             0           0           0       0
# 3145           0             1           0           0       0
# 3158           0             0           0           0       0
# 3197           0             0           1           0       0
# 3218           0             0           0           0       0
# 3250           1             0           0           0       0
# 3377           1             0           0           0       0
#
#      furnishing_type  luxury_score
# 29       unfurnished             0
# 100      unfurnished            62
# 280      unfurnished            45
# 1877     unfurnished            92
# 2002     unfurnished            65
# 2038     unfurnished            15
# 2204     unfurnished            99
# 2213     unfurnished            56
# 2461     unfurnished           120
# 2571     unfurnished            56
# 2867     unfurnished             7
# 2868     unfurnished            21
# 2869     unfurnished            14
# 2870     unfurnished             7
# 2936     unfurnished             0
# 2941     unfurnished             0
# 3008     unfurnished             0
# 3072     unfurnished             0
# 3077     unfurnished             0
# 3143       furnished             0
# 3145       furnished             7
# 3158     unfurnished             0
# 3197     unfurnished            70
# 3218   semifurnished            27
# 3250   semifurnished            73
# 3377   semifurnished            35

# %%
df[df['built_up_area'] < 100].shape
# Out:
# (26, 18)
