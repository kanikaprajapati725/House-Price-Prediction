# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df1=pd.read_csv('Gurgaon_properties_cleaned.csv')
df2=pd.read_csv('Gurgaon_properties_cleaned_v2.csv')

# %%
df1_sorted = df1.sort_values(by='society').reset_index(drop=True)
df2_sorted = df2.sort_values(by='society').reset_index(drop=True)

# %%
print(df1_sorted.shape)
print(df2_sorted.shape)
# Out:
# (3615, 23)
# (3613, 23)

# %%
df1_sorted[['society','price','furnishing_type','luxury_score']]
# Out:
#                                                 society  price  \
# 0                                                     .   7.00
# 1                                      4s aradhya homes   1.90
# 2                                     511 sarahah tower   0.60
# 3                                        aardhya homesh   1.85
# 4                                       ace palm floors   0.97
# 5                                   adani aangan arcade   0.50
# 6                                   adani aangan arcade   0.45
# 7                                   adani aangan arcade   0.45
# 8                                 adani aangan galleria   0.25
# 9                                 adani aangan galleria   0.42
# 10                          adani brahma samsara vilasa   3.40
# 11                          adani brahma samsara vilasa   3.00
# 12                          adani brahma samsara vilasa   3.25
# 13                          adani brahma samsara vilasa   4.49
# ...

# %%
df2_sorted[['society','price','furnishing_type','luxury_score']]
# Out:
#                                                 society  price  \
# 0                                                     .   7.00
# 1                                      4s aradhya homes   1.90
# 2                                     511 sarahah tower   0.60
# 3                                        aardhya homesh   1.85
# 4                                       ace palm floors   0.97
# 5                                   adani aangan arcade   0.45
# 6                                   adani aangan arcade   0.50
# 7                                   adani aangan arcade   0.45
# 8                                 adani aangan galleria   0.42
# 9                                 adani aangan galleria   0.25
# 10                          adani brahma samsara vilasa   3.40
# 11                          adani brahma samsara vilasa   3.35
# 12                          adani brahma samsara vilasa   4.49
# 13                          adani brahma samsara vilasa   3.25
# ...
