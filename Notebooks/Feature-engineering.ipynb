# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('../CSV Files/Gurgaon_properties.csv')

# %%
df.head(2)
# Out:
#   property_type                 society    sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency  sector 7   0.45          5000.0
# 1          flat            apna enclave  sector 3   0.50          7692.0
#
#     area                    areaWithType  bedRoom  bathroom balcony  \
# 0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1  650.0  Carpet area: 650 (60.39 sq.m.)        2         2       1
#
#   additionalRoom  floorNum facing    agePossession  \
# 0  not available       4.0   West  1 to 5 Year Old
# 1  not available       1.0   West     10+ Year Old
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pearl Dental Clinic', 'Taneja Hospital', 'Dr. Ashok Jain', 'Dr. Madan Clinic', 'Geeta Nursing Home Gurgaon', 'Chiranjiv Hospital', 'Dev Man Kathuria Clinic', 'Aryan Hospital', 'Kr Dental Hub', 'Swastik Maternity and Medical Centre', 'Satyam Hospital Gurgaon', 'Ravi Clinic and Health Care Centre', 'D.R. Rajnis Gupta Clinic', 'Esic Hospital Gurugram', 'Gurgaon Eye Centre', 'Bindal Clinic', 'Shiv Mahima Patient Care Bureau', 'Shree Krishna Hospital Gurgaon', 'M.S Hospital', 'My Care Clinic', 'Ankur Clinic and Maternity Home', 'Triveni Hospital Gurgaon', 'Shri Gobind Hospital', 'Navjeevan Hospital and Maternity Centre', 'Lal Superspeciality Hospital', 'Sparsh Hospital Gurgaon', 'Prateek Nursing Home And Polyclinic', 'Jain Sant Phool Chand Ji Charitable Hospital', 'Sarvodya Hospital', 'Bhatnagar Maternity and Nursing Home', 'Tirath Ram Hospitals Pvt Ltd', 'Dr. Sarvejeet Singh', 'Centre For Sight Gurgaon New Railway Road', 'Dr. Ajay S. Gupta Clinic', 'Kidney Clinic', 'Mangalam Hospital and Heart Centre Gurgaon', 'Sethi Hospital Gurgaon', 'Shubham Hospital Gurgaon', 'Kharbanda Maternity and Nursing Home', 'Gupta Hospital Gurgaon', 'Dentecare - Multispeciality Dental Clinic', 'State bank of india', 'Hdfc bank', 'Kotak bank', 'Indian bank', 'Pizza Hut', 'St. Michaels Sr. Sec. School', 'Dronacharya Government College']
# 1                                                                                                                                                ['Chintapurni Mandir', 'Sheetla Mata Mandir', 'State bank ATM', 'Sneh Hospital Gurgaon', 'Jiya Clinic', 'Dr. Mittal Clinic', "Dr. Anurag's Child Care Clinic", 'Yashroop Medical Centre', 'Dr. Sindhu Clinic', 'Bhardwaj Hospital', 'Jain Sant Phool Chand Ji Charitable Hospital', 'Sarvodya Hospital', 'Dr. Hitesh Dawar', 'Prateek Nursing Home And Polyclinic', 'R K Hospital Gurgaon', 'Chirag Hospital Pvt. Ltd', 'Kr Dental Hub', 'Gurgaon Eye Centre', 'Shree Krishna Hospital Gurgaon', 'Dr. Ashok Jain', 'GH Gurgaon', 'Aryan Hospital', 'Dr. Agya Ram Sharma Clinic', 'Pearl Dental Clinic', 'D.R. Rajnis Gupta Clinic', 'Sparsh Hospital Gurgaon', 'Bhatnagar Maternity and Nursing Home', 'Geeta Nursing Home Gurgaon', 'Taneja Hospital', 'Ravi Clinic and Health Care Centre', 'Dr. Sarvejeet Singh', 'Esic Hospital Gurugram', 'Centre For Sight Gurgaon New Railway Road', 'Kidney Clinic', 'Jackson Hospital', 'Jeevan Jyoti Hospital Gurgaon', 'Chiranjiv Hospital', 'Dr. Tomar Clinic', 'Indian bank', 'Kotak bank', 'Hdfc bank', 'State bank of india', 'Pizza Hut', 'St. Michaels Sr. Sec. School', 'Lieutenant Atul Kataria School', 'Dronacharya Government College', 'Gurgaon railway station', 'Gurgaon railway station', 'Gurgaon railway station']
#
#                                                                                                                                                                                                                                                        furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 1       ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Geyser', '3 Light', '1 Curtains', '1 Chimney', '1 Modular Kitchen', 'No AC', 'No Bed', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
#
#                                                                                                    features
# 0  ['Feng Shui / Vaastu Compliant', 'Security / Fire Alarm', 'Lift(s)', 'Water Storage', 'Visitor Parking']
# 1                ['Security / Fire Alarm', 'Maintenance Staff', 'Water Storage', 'Park', 'Visitor Parking']

# %% [markdown]
# ## 1.areaWithType

# %%
df.sample(5)[['area','areaWithType']]
# Out:
#         area  \
# 2073  1530.0
# 1275  3150.0
# 2706   587.0
# 1991  1296.0
# 1251  2132.0
#
#                                                                                                                 areaWithType
# 2073                                                                                        Carpet area: 1530 (142.14 sq.m.)
# 1275                                                                                  Super Built up area 3150(292.64 sq.m.)
# 2706                                                                                    Super Built up area 576(53.51 sq.m.)
# 1991                                                                                       Built Up area: 1296 (120.4 sq.m.)
# 1251  Super Built up area 2132(198.07 sq.m.)Built Up area: 1800 sq.ft. (167.23 sq.m.)Carpet area: 1500 sq.ft. (139.35 sq.m.)

# %%
def get_super_built_up_area(text):
    match = re.search(r'Super Built up area (\d+\.?\d*)', text)
    if match:
        return float(match.group(1))
    return None

# %%
def get_area(text, area_type):
    match = re.search(area_type + r'\s*:\s*(\d+\.?\d*)', text)
    if match:
        return float(match.group(1))
    return None

# %%
def convert_to_sqft(text, area_value):
    if area_value is None:
        return None
    match = re.search(r'{} \((\d+\.?\d*) sq.m.\)'.format(area_value), text)
    if match:
        sq_m_value = float(match.group(1))
        return sq_m_value * 10.7639  # conversion factor from sq.m. to sqft
    return area_value

# %%
df['super_built_up_area'] = df['areaWithType'].apply(get_super_built_up_area)
df['super_built_up_area'] = df.apply(lambda x: convert_to_sqft(x['areaWithType'], x['super_built_up_area']), axis=1)

df['built_up_area'] = df['areaWithType'].apply(lambda x: get_area(x, 'Built Up area'))
df['built_up_area'] = df.apply(lambda x: convert_to_sqft(x['areaWithType'], x['built_up_area']), axis=1)

df['carpet_area'] = df['areaWithType'].apply(lambda x: get_area(x, 'Carpet area'))
df['carpet_area'] = df.apply(lambda x: convert_to_sqft(x['areaWithType'], x['carpet_area']), axis=1)

# %%
df[['price','property_type','area','areaWithType','super_built_up_area','built_up_area','carpet_area']].sample(5)
# Out:
#       price property_type    area  \
# 1906   1.45          flat  1600.0
# 3242   0.59         house   585.0
# 2341   0.32          flat   554.0
# 2550   0.65          flat   891.0
# 442    2.45          flat  2018.0
#
#                                                                                                                 areaWithType  \
# 1906                                          Super Built up area 1495(138.89 sq.m.)Built Up area: 1494 sq.ft. (138.8 sq.m.)
# 3242                                                                                              Plot area 585(54.35 sq.m.)
# 2341                                                                                          Carpet area: 554 (51.47 sq.m.)
# 2550                                                   Built Up area: 822 (76.37 sq.m.)Carpet area: 520 sq.ft. (48.31 sq.m.)
# 442   Super Built up area 2018(187.48 sq.m.)Built Up area: 1800 sq.ft. (167.23 sq.m.)Carpet area: 1614 sq.ft. (149.95 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 1906               1495.0         1494.0          NaN
# 3242                  NaN            NaN          NaN
# 2341                  NaN            NaN        554.0
# 2550                  NaN          822.0        520.0
# 442                2018.0         1800.0       1614.0

# %%
df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))][['price','property_type','area','areaWithType','super_built_up_area','built_up_area','carpet_area']].shape
# Out:
# (530, 7)

# %%
df[df['areaWithType'].str.contains('Plot')][['price','property_type','area','areaWithType','super_built_up_area','built_up_area','carpet_area']].head(5)
# Out:
#       price property_type    area                 areaWithType  \
# 2801   5.25         house  2610.0  Plot area 290(242.48 sq.m.)
# 2802   2.10         house   549.0       Plot area 61(51 sq.m.)
# 2803   5.00         house  1161.0  Plot area 129(107.86 sq.m.)
# 2804   3.00         house   558.0    Plot area 62(51.84 sq.m.)
# 2805   4.50         house  1152.0  Plot area 128(107.02 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 2801                  NaN            NaN          NaN
# 2802                  NaN            NaN          NaN
# 2803                  NaN            NaN          NaN
# 2804                  NaN            NaN          NaN
# 2805                  NaN            NaN          NaN

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                    17
# price_per_sqft           17
# area                     17
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# additionalRoom            0
# floorNum                 19
# facing                 1021
# agePossession             1
# nearbyLocations         164
# furnishDetails          939
# features                575
# super_built_up_area    1749
# built_up_area          2496
# carpet_area            1765
# dtype: int64

# %%
all_nan_df=df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())][['price','property_type','area','areaWithType','super_built_up_area','built_up_area','carpet_area']]

# %%
all_nan_df.head()
# Out:
#       price property_type    area                 areaWithType  \
# 2801   5.25         house  2610.0  Plot area 290(242.48 sq.m.)
# 2802   2.10         house   549.0       Plot area 61(51 sq.m.)
# 2803   5.00         house  1161.0  Plot area 129(107.86 sq.m.)
# 2804   3.00         house   558.0    Plot area 62(51.84 sq.m.)
# 2805   4.50         house  1152.0  Plot area 128(107.02 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 2801                  NaN            NaN          NaN
# 2802                  NaN            NaN          NaN
# 2803                  NaN            NaN          NaN
# 2804                  NaN            NaN          NaN
# 2805                  NaN            NaN          NaN

# %%
all_nan_index = df[((df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull()))][['price','property_type','area','areaWithType','super_built_up_area','built_up_area','carpet_area']].index

# %%
def extract_plot_area(area_with_type):
    match = re.search(r'Plot area (\d+\.?\d*)', area_with_type)
    if match:
        return float(match.group(1))
    else:
        return None

# %%
all_nan_df['built_up_area'] = all_nan_df['areaWithType'].apply(extract_plot_area)

# %%
all_nan_df.head()
# Out:
#       price property_type    area                 areaWithType  \
# 2801   5.25         house  2610.0  Plot area 290(242.48 sq.m.)
# 2802   2.10         house   549.0       Plot area 61(51 sq.m.)
# 2803   5.00         house  1161.0  Plot area 129(107.86 sq.m.)
# 2804   3.00         house   558.0    Plot area 62(51.84 sq.m.)
# 2805   4.50         house  1152.0  Plot area 128(107.02 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 2801                  NaN          290.0          NaN
# 2802                  NaN           61.0          NaN
# 2803                  NaN          129.0          NaN
# 2804                  NaN           62.0          NaN
# 2805                  NaN          128.0          NaN

# %%
def convert_scale(row):
    if np.isnan(row['area']) or np.isnan(row['built_up_area']):
        return row['built_up_area']
    else:
        if round(row['area']/row['built_up_area']) == 9.0:
            return row['built_up_area'] * 9
        elif round(row['area']/row['built_up_area']) == 11.0:
            return row['built_up_area'] * 10.7
        else:
            return row['built_up_area']

# %%
all_nan_df['built_up_area'] = all_nan_df.apply(convert_scale,axis=1)

# %%
all_nan_df.head()
# Out:
#       price property_type    area                 areaWithType  \
# 2801   5.25         house  2610.0  Plot area 290(242.48 sq.m.)
# 2802   2.10         house   549.0       Plot area 61(51 sq.m.)
# 2803   5.00         house  1161.0  Plot area 129(107.86 sq.m.)
# 2804   3.00         house   558.0    Plot area 62(51.84 sq.m.)
# 2805   4.50         house  1152.0  Plot area 128(107.02 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 2801                  NaN         2610.0          NaN
# 2802                  NaN          549.0          NaN
# 2803                  NaN         1161.0          NaN
# 2804                  NaN          558.0          NaN
# 2805                  NaN         1152.0          NaN

# %%
df.update(all_nan_df)

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6722.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
#   additionalRoom  floorNum facing       agePossession  \
# 0  not available       4.0   West     1 to 5 Year Old
# 1  not available       1.0   West        10+ Year Old
# 2  not available      12.0    NaN     0 to 1 Year Old
# 3     study room       2.0    NaN            Dec 2023
# 4     study room       5.0    NaN  Under Construction
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pearl Dental Clinic', 'Taneja Hospital', 'Dr. Ashok Jain', 'Dr. Madan Clinic', 'Geeta Nursing Home Gurgaon', 'Chiranjiv Hospital', 'Dev Man Kathuria Clinic', 'Aryan Hospital', 'Kr Dental Hub', 'Swastik Maternity and Medical Centre', 'Satyam Hospital Gurgaon', 'Ravi Clinic and Health Care Centre', 'D.R. Rajnis Gupta Clinic', 'Esic Hospital Gurugram', 'Gurgaon Eye Centre', 'Bindal Clinic', 'Shiv Mahima Patient Care Bureau', 'Shree Krishna Hospital Gurgaon', 'M.S Hospital', 'My Care Clinic', 'Ankur Clinic and Maternity Home', 'Triveni Hospital Gurgaon', 'Shri Gobind Hospital', 'Navjeevan Hospital and Maternity Centre', 'Lal Superspeciality Hospital', 'Sparsh Hospital Gurgaon', 'Prateek Nursing Home And Polyclinic', 'Jain Sant Phool Chand Ji Charitable Hospital', 'Sarvodya Hospital', 'Bhatnagar Maternity and Nursing Home', 'Tirath Ram Hospitals Pvt Ltd', 'Dr. Sarvejeet Singh', 'Centre For Sight Gurgaon New Railway Road', 'Dr. Ajay S. Gupta Clinic', 'Kidney Clinic', 'Mangalam Hospital and Heart Centre Gurgaon', 'Sethi Hospital Gurgaon', 'Shubham Hospital Gurgaon', 'Kharbanda Maternity and Nursing Home', 'Gupta Hospital Gurgaon', 'Dentecare - Multispeciality Dental Clinic', 'State bank of india', 'Hdfc bank', 'Kotak bank', 'Indian bank', 'Pizza Hut', 'St. Michaels Sr. Sec. School', 'Dronacharya Government College']
# 1                                                                                                                                                ['Chintapurni Mandir', 'Sheetla Mata Mandir', 'State bank ATM', 'Sneh Hospital Gurgaon', 'Jiya Clinic', 'Dr. Mittal Clinic', "Dr. Anurag's Child Care Clinic", 'Yashroop Medical Centre', 'Dr. Sindhu Clinic', 'Bhardwaj Hospital', 'Jain Sant Phool Chand Ji Charitable Hospital', 'Sarvodya Hospital', 'Dr. Hitesh Dawar', 'Prateek Nursing Home And Polyclinic', 'R K Hospital Gurgaon', 'Chirag Hospital Pvt. Ltd', 'Kr Dental Hub', 'Gurgaon Eye Centre', 'Shree Krishna Hospital Gurgaon', 'Dr. Ashok Jain', 'GH Gurgaon', 'Aryan Hospital', 'Dr. Agya Ram Sharma Clinic', 'Pearl Dental Clinic', 'D.R. Rajnis Gupta Clinic', 'Sparsh Hospital Gurgaon', 'Bhatnagar Maternity and Nursing Home', 'Geeta Nursing Home Gurgaon', 'Taneja Hospital', 'Ravi Clinic and Health Care Centre', 'Dr. Sarvejeet Singh', 'Esic Hospital Gurugram', 'Centre For Sight Gurgaon New Railway Road', 'Kidney Clinic', 'Jackson Hospital', 'Jeevan Jyoti Hospital Gurgaon', 'Chiranjiv Hospital', 'Dr. Tomar Clinic', 'Indian bank', 'Kotak bank', 'Hdfc bank', 'State bank of india', 'Pizza Hut', 'St. Michaels Sr. Sec. School', 'Lieutenant Atul Kataria School', 'Dronacharya Government College', 'Gurgaon railway station', 'Gurgaon railway station', 'Gurgaon railway station']
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['Huda City Metro', 'Golf Course extn road', 'Rajiv Chowk', 'IGI Airport', 'IMT Sohna', 'Damdama Lake']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ['Sector 55-56 Metro station', 'Bestech Central Square Mall', 'Golf Course Ext Road', 'Badshahpur Sohna Rd Hwy', 'ORCHIDS The International School', 'Sushant University', 'Marengo Asia Hospitals', 'Indira Gandhi Intl Airport', 'Gurgaon Railway Station']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. Sarkar Clinic', 'Sagar Clinic', 'Orris Community Center', 'Vijay Petrol Pump', 'HP Petrol Pump', 'Essar Petrol Pump', 'Indian Oil', 'Pizza Hut', 'KFC']
#
#                                                                                                                                                                                                                                                        furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 1       ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Geyser', '3 Light', '1 Curtains', '1 Chimney', '1 Modular Kitchen', 'No AC', 'No Bed', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 2                                                                                                                                                                                                                                                                 NaN
# 3                                                                                                                                                                                                                                                                 NaN
# 4                                                                                                                                                                                                                                                                  []
#
#                                                                                                                                                                                                                                                                                 features  \
# 0                                                                                                                                                                               ['Feng Shui / Vaastu Compliant', 'Security / Fire Alarm', 'Lift(s)', 'Water Storage', 'Visitor Parking']
# 1                                                                                                                                                                                             ['Security / Fire Alarm', 'Maintenance Staff', 'Water Storage', 'Park', 'Visitor Parking']
# 2                                                                                                                    ['Power Back-up', 'Feng Shui / Vaastu Compliant', 'Intercom Facility', 'Lift(s)', 'Swimming Pool', 'Park', 'Fitness Centre / GYM', 'Club house / Community Center']
# 3  ['Security / Fire Alarm', 'Private Garden / Terrace', 'Lift(s)', 'Maintenance Staff', 'False Ceiling Lighting', 'Water Storage', 'Visitor Parking', 'Swimming Pool', 'Natural Light', 'Airy Rooms', 'Fitness Centre / GYM', 'Club house / Community Center', 'Water softening plant']
# 4                                                                                                                                                                                                                                                                                    NaN
#
#    super_built_up_area  built_up_area  carpet_area
# 0                  NaN            NaN        900.0
# 1                  NaN            NaN        650.0
# 2                  NaN            NaN        595.0
# 3                  NaN            NaN       1200.0
# 4               1345.0            NaN          NaN

# %% [markdown]
# ## 2. additionalRoom

# %%
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# not available                                    1483
# servant room                                      681
# study room                                        240
# others                                            217
# pooja room                                        161
# store room                                         97
# study room,servant room                            96
# pooja room,servant room                            81
# pooja room,study room,servant room,store room      70
# servant room,others                                55
# pooja room,study room,servant room,others          54
# pooja room,study room,servant room                 53
# servant room,pooja room                            38
# servant room,store room                            30
# study room,others                                  25
# pooja room,study room                              21
# pooja room,others                                  14
# pooja room,store room                              13
# pooja room,store room,study room,servant room      12
# study room,servant room,store room                 11
# servant room,study room                            11
# pooja room,servant room,others                     11
# servant room,study room,pooja room,store room      10
# study room,pooja room                              10
# store room,servant room                             8
# study room,servant room,pooja room,store room       8
# study room,pooja room,servant room                  7
# pooja room,servant room,store room                  7
# study room,servant room,others                      6
# others,servant room                                 6
# pooja room,study room,store room                    6
# servant room,pooja room,store room                  6
# pooja room,servant room,study room,store room       5
# study room,servant room,store room,pooja room       5
# store room,pooja room                               5
# servant room,store room,pooja room                  4
# study room,servant room,pooja room                  4
# study room,pooja room,store room                    4
# servant room,pooja room,study room,store room       3
# servant room,study room,pooja room                  3
# pooja room,study room,others                        3
# servant room,others,pooja room                      3
# pooja room,study room,store room,servant room       3
# study room,pooja room,servant room,store room       2
# store room,pooja room,study room,servant room       2
# study room,pooja room,store room,servant room       2
# store room,pooja room,study room                    2
# store room,pooja room,servant room                  2
# servant room,study room,store room                  2
# study room,store room                               2
# servant room,study room,others                      1
# store room,pooja room,servant room,study room       1
# store room,servant room,pooja room                  1
# store room,study room,servant room                  1
# pooja room,store room,servant room                  1
# store room,servant room,study room,pooja room       1
# servant room,store room,study room,pooja room       1
# store room,study room                               1
# others,study room                                   1
# study room,store room,pooja room                    1
# servant room,study room,store room,pooja room       1
# servant room,pooja room,store room,study room       1
# servant room,pooja room,study room                  1
# servant room,others,store room,pooja room           1
# study room,others,servant room                      1
# Name: count, dtype: int64

# %%
new_cols = ['study room', 'servant room', 'store room', 'pooja room', 'others']
for col in new_cols:
    df[col] = df['additionalRoom'].str.contains(col).astype(int)

# %%
df.head(2)
# Out:
#   property_type                 society    sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency  sector 7   0.45          5000.0
# 1          flat            apna enclave  sector 3   0.50          7692.0
#
#     area                    areaWithType  bedRoom  bathroom balcony  \
# 0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1  650.0  Carpet area: 650 (60.39 sq.m.)        2         2       1
#
#   additionalRoom  floorNum facing    agePossession  \
# 0  not available       4.0   West  1 to 5 Year Old
# 1  not available       1.0   West     10+ Year Old
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pearl Dental Clinic', 'Taneja Hospital', 'Dr. Ashok Jain', 'Dr. Madan Clinic', 'Geeta Nursing Home Gurgaon', 'Chiranjiv Hospital', 'Dev Man Kathuria Clinic', 'Aryan Hospital', 'Kr Dental Hub', 'Swastik Maternity and Medical Centre', 'Satyam Hospital Gurgaon', 'Ravi Clinic and Health Care Centre', 'D.R. Rajnis Gupta Clinic', 'Esic Hospital Gurugram', 'Gurgaon Eye Centre', 'Bindal Clinic', 'Shiv Mahima Patient Care Bureau', 'Shree Krishna Hospital Gurgaon', 'M.S Hospital', 'My Care Clinic', 'Ankur Clinic and Maternity Home', 'Triveni Hospital Gurgaon', 'Shri Gobind Hospital', 'Navjeevan Hospital and Maternity Centre', 'Lal Superspeciality Hospital', 'Sparsh Hospital Gurgaon', 'Prateek Nursing Home And Polyclinic', 'Jain Sant Phool Chand Ji Charitable Hospital', 'Sarvodya Hospital', 'Bhatnagar Maternity and Nursing Home', 'Tirath Ram Hospitals Pvt Ltd', 'Dr. Sarvejeet Singh', 'Centre For Sight Gurgaon New Railway Road', 'Dr. Ajay S. Gupta Clinic', 'Kidney Clinic', 'Mangalam Hospital and Heart Centre Gurgaon', 'Sethi Hospital Gurgaon', 'Shubham Hospital Gurgaon', 'Kharbanda Maternity and Nursing Home', 'Gupta Hospital Gurgaon', 'Dentecare - Multispeciality Dental Clinic', 'State bank of india', 'Hdfc bank', 'Kotak bank', 'Indian bank', 'Pizza Hut', 'St. Michaels Sr. Sec. School', 'Dronacharya Government College']
# 1                                                                                                                                                ['Chintapurni Mandir', 'Sheetla Mata Mandir', 'State bank ATM', 'Sneh Hospital Gurgaon', 'Jiya Clinic', 'Dr. Mittal Clinic', "Dr. Anurag's Child Care Clinic", 'Yashroop Medical Centre', 'Dr. Sindhu Clinic', 'Bhardwaj Hospital', 'Jain Sant Phool Chand Ji Charitable Hospital', 'Sarvodya Hospital', 'Dr. Hitesh Dawar', 'Prateek Nursing Home And Polyclinic', 'R K Hospital Gurgaon', 'Chirag Hospital Pvt. Ltd', 'Kr Dental Hub', 'Gurgaon Eye Centre', 'Shree Krishna Hospital Gurgaon', 'Dr. Ashok Jain', 'GH Gurgaon', 'Aryan Hospital', 'Dr. Agya Ram Sharma Clinic', 'Pearl Dental Clinic', 'D.R. Rajnis Gupta Clinic', 'Sparsh Hospital Gurgaon', 'Bhatnagar Maternity and Nursing Home', 'Geeta Nursing Home Gurgaon', 'Taneja Hospital', 'Ravi Clinic and Health Care Centre', 'Dr. Sarvejeet Singh', 'Esic Hospital Gurugram', 'Centre For Sight Gurgaon New Railway Road', 'Kidney Clinic', 'Jackson Hospital', 'Jeevan Jyoti Hospital Gurgaon', 'Chiranjiv Hospital', 'Dr. Tomar Clinic', 'Indian bank', 'Kotak bank', 'Hdfc bank', 'State bank of india', 'Pizza Hut', 'St. Michaels Sr. Sec. School', 'Lieutenant Atul Kataria School', 'Dronacharya Government College', 'Gurgaon railway station', 'Gurgaon railway station', 'Gurgaon railway station']
#
#                                                                                                                                                                                                                                                        furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 1       ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Geyser', '3 Light', '1 Curtains', '1 Chimney', '1 Modular Kitchen', 'No AC', 'No Bed', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
#
#                                                                                                    features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / Fire Alarm', 'Lift(s)', 'Water Storage', 'Visitor Parking']
# 1                ['Security / Fire Alarm', 'Maintenance Staff', 'Water Storage', 'Park', 'Visitor Parking']
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        900.0           0             0
# 1                  NaN            NaN        650.0           0             0
#
#    store room  pooja room  others
# 0           0           0       0
# 1           0           0       0

# %% [markdown]
# ## 3.agePossession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# 1 to 5 Year Old       1632
# 5 to 10 Year Old       556
# 0 to 1 Year Old        493
# undefined              296
# 10+ Year Old           291
# Under Construction      86
# Within 6 months         64
# Within 3 months         24
# Dec 2023                19
# By 2023                 17
# By 2024                 16
# Dec 2024                15
# Mar 2024                12
# Jan 2024                 7
# Oct 2024                 6
# Aug 2023                 6
# Dec 2025                 6
# Jun 2024                 6
# Nov 2023                 5
# By 2025                  4
# Oct 2023                 4
# Aug 2024                 4
# Sep 2023                 4
# Feb 2024                 3
# Jul 2024                 3
# Jan 2025                 3
# Nov 2024                 3
# May 2024                 3
# Jan 2026                 2
# Jul 2025                 2
# Mar 2025                 2
# Jun 2027                 2
# Aug 2025                 2
# By 2027                  2
# Jul 2027                 2
# Apr 2026                 2
# Dec 2026                 2
# Sep 2025                 2
# Aug 2026                 1
# Jun 2025                 1
# Mar 2026                 1
# Jan 2028                 1
# Apr 2024                 1
# Sep 2027                 1
# Nov 2025                 1
# Jul 2026                 1
# Jan 2027                 1
# Oct 2025                 1
# Name: count, dtype: int64

# %%
def categorize_age_possession(value):
    if pd.isna(value):
        return "Undefined"
    if "0 to 1 Year Old" in value or "Within 6 months" in value or "Within 3 months" in value:
        return "New Property"
    if "1 to 5 Year Old" in value:
        return "Relatively New"
    if "5 to 10 Year Old" in value:
        return "Moderately Old"
    if "10+ Year Old" in value:
        return "Old Property"
    if "Under Construction" in value or "By" in value:
        return "Under Construction"

    try:
        year = int(value.split()[-1])
        current_year = 2026
    
        if year < 2025:
            return "Relatively New"
        elif year <= current_year:
            return "New Property"
        else:
            return "Under Construction"
    
    except:
        return "Undefined"

# %%
df['agePossession'] = df['agePossession'].apply(categorize_age_possession)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1733
# New Property           610
# Moderately Old         556
# Undefined              297
# Old Property           291
# Under Construction     132
# Name: count, dtype: int64

# %% [markdown]
# ## 4.furnishDetails

# %%
df.sample(5)[['furnishDetails']]
# Out:
#                                                                                                                                                                                                                                                             furnishDetails
# 1864              ['1 Water Purifier', '7 Fan', '1 Exhaust Fan', '1 Dining Table', '5 Geyser', '1 Stove', '99 Light', '7 AC', '1 Chimney', '6 Curtains', '1 Modular Kitchen', '7 Wardrobe', '1 Sofa', '1 Microwave', 'No Bed', 'No Fridge', 'No TV', 'No Washing Machine']
# 3029                                                                                                                                                                                                                                                                   NaN
# 2018  ['1 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']
# 3521     ['9 Wardrobe', '15 Fan', '1 Exhaust Fan', '12 Geyser', '60 Light', '1 Modular Kitchen', '1 Chimney', 'No AC', 'No Bed', 'No Curtains', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 3564       ['8 Wardrobe', '12 Fan', '1 Exhaust Fan', '8 Geyser', '12 Light', '8 AC', '1 Modular Kitchen', '2 Chimney', 'No Bed', 'No Curtains', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']

# %%
all_items = []

for row in df['furnishDetails'].dropna():

    parts = row.replace('[', '').replace(']', '').replace("'", '').split(', ')

    for part in parts:
        if len(part)==0:
            continue
        words = part.split()

        if words[0].isdigit():
            item = ' '.join(words[1:])

        elif words[0] == 'No':
            item = ' '.join(words[1:])

        all_items.append(item)

items = list(set(all_items))



def get_count(text, item):

    if pd.isna(text):
        return 0

    parts = text.replace('[', '').replace(']', '').replace("'", '').split(', ')

    for part in parts:

        words = part.split()

        if len(words) == 0:
            continue

        if words[0] == 'No':

            curr_item = ' '.join(words[1:])

            if curr_item == item:
                return 0

        elif words[0].isdigit():

            curr_item = ' '.join(words[1:])

            if curr_item == item:
                return int(words[0])

    return 0


furnishings_df = pd.DataFrame()

for item in items:
    furnishings_df[item] = df['furnishDetails'].apply(
        lambda x: get_count(x, item)
    )

# %%
furnishings_df.shape
# Out:
# (3619, 18)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(furnishings_df)

# %%
wcss_reduced = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(scaled_data)
    wcss_reduced.append(kmeans.inertia_)

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(1,11), wcss_reduced, marker='o', linestyle='--')
plt.title('Elbow Method For Optimal Number of Clusters (Reduced Range)')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
n_clusters = 3

kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(scaled_data)
cluster_assignments = kmeans.predict(scaled_data)

# %%
df['furnishing_type'] = cluster_assignments

# %%
df.sample(5)[['furnishDetails','furnishing_type']]
# Out:
#                                                                                                                                                                                                                                                           furnishDetails  \
# 3056                                                                                                                                                                                                                                                                 NaN
# 2704                                                                                                                                                                                                                                                                 NaN
# 3114  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 3421               ['1 Water Purifier', '9 Fan', '1 Fridge', '1 Exhaust Fan', '1 Dining Table', '8 Geyser', '1 Stove', '12 Light', '8 AC', '4 TV', '1 Modular Kitchen', '1 Chimney', '1 Curtains', '6 Wardrobe', '1 Sofa', '1 Washing Machine', '1 Microwave', 'No Bed']
# 3574   ['1 Wardrobe', '1 Fan', '1 Geyser', '1 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
#
#       furnishing_type
# 3056                0
# 2704                0
# 3114                0
# 3421                1
# 3574                0

# %%
furnishings_df['furnishing_type'] = df['furnishing_type']
furnishings_df.groupby('furnishing_type').mean()
# Out:
#                  Microwave  Washing Machine  Exhaust Fan  Wardrobe    Geyser  \
# furnishing_type
# 0                 0.002923         0.000835     0.053445  0.292693  0.146138
# 1                 0.830846         0.721393     0.860697  4.980100  4.338308
# 2                 0.073314         0.011730     0.876833  3.363636  2.915934
#
#                       Bed      Light        TV        AC  Dining Table  \
# furnishing_type
# 0                0.019624   1.242589  0.005428  0.542797      0.003340
# 1                1.592040  12.487562  1.333333  4.850746      0.472637
# 2                0.066471  13.365591  0.057674  2.892473      0.021505
#
#                      Sofa  Water Purifier       Fan   Chimney  Curtains  \
# furnishing_type
# 0                0.007098        0.005428  0.615449  0.069729  0.023382
# 1                0.542289        0.746269  6.283582  1.074627  1.746269
# 2                0.010753        0.185728  5.657869  0.833822  0.661779
#
#                    Fridge     Stove  Modular Kitchen
# furnishing_type
# 0                0.001670  0.014614         0.149061
# 1                0.855721  0.771144         0.905473
# 2                0.011730  0.266862         0.902248

# %% [markdown]
# ## 5.features

# %%
df[['society','features']]
# Out:
#                                                 society  \
# 0                                maa bhagwati residency
# 1                                          apna enclave
# 2                                tulsiani easy in homes
# 3                                   smart world orchard
# 4                                      parkwood westend
# 5                        signature global infinity mall
# 6                                            the cocoon
# 7                                           ats triumph
# 8                                     vatika xpressions
# 9                                        raheja revanta
# 10                             signature global city 81
# 11                                    hcbs sports ville
# 12                                   supertech araville
# 13                                               godrej
# 14                                 shree vardhman flora
# 15                                           sobha city
# 16                                         senate court
# 17                 shapoorji pallonji joyville gurugram
# 18                    signature global orchard avenue 2
# 19                           central park flower valley
# 20                                     smart world gems
# 21                                       bestech altura
# 22                                     smart world gems
# 23                               emaar imperial gardens
# 24                              la vida by tata housing
# 25                                          the serenas
# 26                                       m3m golfestate
# 27             central park resort belgravia residences
# 28                                        apex builders
# 29                                       godrej habitat
# 30                                  ompee k s residency
# 31                                          bhawna cghs
# 32                                  adani aangan arcade
# 33                                      sare green parc
# 34                                 shree vardhman flora
# 35                                       supertech hues
# 36                                    chintels paradiso
# 37                               breez global hill view
# 38                                           ild greens
# 39                                 ansal sushant lok ci
# 40                                     ashiana mulberry
# 41                                      godrej meridien
# 42                                    mapsko casa bella
# 43                                signature global park
# 44                                 dlf new town heights
# 45                                           paras dews
# 46                                           godrej air
# 47                                       dlf the primus
# 48                     emaar mgf emerald floors premier
# 49                                     dlf regency park
# 50                                   supertech araville
# 51                                signature global park
# 52                             maxworth city residences
# 53                                         deepak minda
# 54                                       pivotal devaan
# 55                               unitech the residences
# 56                                           chd avenue
# 57                               silverglades the melia
# 58              sare crescent parc royal greens phase 1
# 59                                   umang winter hills
# 60                                      ramprastha skyz
# 61                                     4s aradhya homes
# 62                                           ild greens
# 63                               bptp freedom park life
# 64                                       godrej habitat
# 65                                      ramsons kshitij
# 66                                    sidhartha ncr one
# 67                                       raheja sampada
# 68                                signature the serenas
# 69                             pareena laxmi apartments
# 70                                  satya the hermitage
# 71                                     smart world gems
# 72                                    gls arawali homes
# 73                                signature global park
# 74                               bestech park view city
# 75                                 shree vardhman flora
# 76                                  afnhb jalvayu vihar
# 77                                        m3m soulitude
# 78                                        pyramid elite
# 79                              emaar mgf palm terraces
# 80                                    hcbs sports ville
# 81                                   puri the aravallis
# 82                          brisk lumbini terrace homes
# 83                               huda ashok vihar phase
# 84                                              my home
# 85                                signature global city
# 86                                          m3m heights
# 87                                signature global park
# 88                                signature global park
# 89                                   godrej nature plus
# 90                                       supertech hues
# 91                                 dlf new town heights
# 92         central park flower valley aqua front towers
# 93                                   ambience creacions
# 94                            signature global city 63a
# 95                                         godrej oasis
# 96                                          m3m skycity
# 97                                   supertech araville
# 98                                  smart world orchard
# 99                                    hcbs sports ville
# 100                                  emaar palm premier
# 101                                  godrej nature plus
# 102                                         godrej aria
# 103                                     ramsons kshitij
# 104                                       conscient one
# 105                            pareena laxmi apartments
# 106                                       pyramid elite
# 107                                      raheja revanta
# 108                                         m3m skycity
# 109                               signature the roselia
# 110                                      not applicable
# 111                                  godrej nature plus
# 112                                     ramprastha city
# 113                                     smartworld 1dxp
# 114                         ansal housing highland park
# 115                               czar mahira homes 63a
# 116                                breez global heights
# 117                                 trisara our homes 3
# 118                                       m3m soulitude
# 119                                emaar mgf palm hills
# 120                                     ramprastha city
# 121                            pareena coban residences
# 122                             la vida by tata housing
# 123                             la vida by tata housing
# 124                         godrej summit premia towers
# 125                                          ardee city
# 126                               m3m one key resiments
# 127                                    ansal heights 86
# 128                                          mvn athens
# 129                               signature the serenas
# 130                        sushant lok 1 builder floors
# 131                                umang monsoon breeze
# 132                                       gls avenue 51
# 133                             signature global solera
# 134                                  supertech araville
# 135                                         greenopolis
# 136        central park flower valley aqua front towers
# 137                                          sare homes
# 138           vatika sovereign next sector-82 a gurgaon
# 139                                    smart world gems
# 140                                       micasa sec 68
# 141                                     eldeco accolade
# 142                                          hero homes
# 143                                         shyam sadan
# 144                                         m3m heights
# 145                                  supertech hilltown
# 146                                     raheja vedaanta
# 147                                          bptp terra
# 148                                         green court
# 149                              m3m golf hills phase 1
# 150                               pyramid urban homes 2
# 151                                         m3m heights
# 152                                  godrej nature plus
# 153                                 smart world orchard
# 154                                       ashiana anmol
# 155                                signature signum 95a
# 156                                  umang winter hills
# 157                                      aardhya homesh
# 158                                          rof ananda
# 159                                    smart world gems
# 160                                      assotech blith
# 161                                        raheja vanya
# 162                                  vatika inxt floors
# 163                                 palam vihar society
# 164                                        godrej oasis
# 165                                dlf new town heights
# 166                                dlf new town heights
# 167                                      supertech hues
# 168                              krrish florence estate
# 169                            piedmont taksila heights
# 170                                  experion heartsong
# 171                                         ss the leaf
# 172                                          m3m urbana
# 173                                 aipl zen residences
# 174                                   dlf regal gardens
# 175                                          godrej air
# 176                               suncity vatsal valley
# 177                              project krishna colony
# 178                                          mvn athens
# 179                                   m3m antalya hills
# 180                          central park flower valley
# 181                                         m3m capital
# 182                                       ansal heights
# 183                                        malibu towne
# 184                                 aipl zen residences
# 185                                         m3m heights
# 186                                   hcbs sports ville
# 187                                   hcbs sports ville
# 188                                housing apna enclave
# 189                                      assotech blith
# 190                                     pareena mi casa
# 191                                     suncity heights
# 192                                          lotus homz
# 193                      ramson kshitij sec-95 gurugram
# 194                                 maruti vihar colony
# 195                                         m3m heights
# 196                                    supertech basera
# 197                      signature global the millennia
# 198                                       m3m soulitude
# 199                                        raheja vanya
# 200          ganpati apartment  2, laxman vihar phase 1
# 201                               ramprastha the atrium
# 202                                      m3m golfestate
# 203                                     eldeco accolade
# 204                                         m3m heights
# 205                                         m3m heights
# 206                               vatika sovereign next
# 207                                         m3m heights
# 208                                         m3m heights
# 209                                         m3m heights
# 210                                        allure homes
# 211                                         zara aavaas
# 212                             sidhartha ncr one phase
# 213                                          chd avenue
# 214                          ramprastha the edge towers
# 215                                  supertech araville
# 216                                   imperia aashiyara
# 217                             la vida by tata housing
# 218                shapoorji pallonji joyville gurugram
# 219                                 smart world orchard
# 220                                  supertech araville
# 221                                 smart world orchard
# 222                              unitech the residences
# 223                              emaar imperial gardens
# 224                                          sare homes
# 225                                         greenopolis
# 226                                      pivotal devaan
# 227              m m residency, krishna colony, gurgaon
# 228                             signature global park 4
# 229                                          chd avenue
# 230                                park royal apartment
# 231             vatika boulevard residences and heights
# 232                      signature global the millennia
# 233                                         m3m heights
# 234                shapoorji pallonji joyville gurugram
# 235                                      tulip monsella
# 236                       shyamkunj ashok vihar pahse 2
# 237                                  godrej nature plus
# 238                                         m3m heights
# 239                                      m3m the marina
# 240                                     emaar digihomes
# 241                                umang monsoon breeze
# 242                                     mapsko paradise
# 243                                      cancon enclave
# 244                                       tata primanti
# 245                                   mrg world ultimus
# 246                          sonata group housing gh 24
# 247                                       bptp pedestal
# 248                                 smart world orchard
# 249                                hsiidc sidco aravali
# 250                                         godrej aria
# 251                                      assotech blith
# 252                                  sare crescent parc
# 253                                      unitech vistas
# 254                                  supertech araville
# 255                         ansal housing highland park
# 256                                         tulip white
# 257                                   mapsko casa bella
# 258                            unitech uniworld gardens
# 259                                           ild grand
# 260                                         m3m capital
# 261                                      unitech vistas
# 262                          ramprastha the edge towers
# 263                                    smart world gems
# 264                               sapphire eighty three
# 265                            pareena coban residences
# 266                                  sare crescent parc
# 267                                       dlf the grove
# 268                                   baani city center
# 269                                   indiabulls enigma
# 270                                         ss the leaf
# 271                                sukhshanti apartment
# 272                                      m3m golfestate
# 273                         bestech park view residency
# 274                                          ss almeria
# 275                                         jmd gardens
# 276                                 ireo victory valley
# 277                                     emaar digihomes
# 278                                  godrej nature plus
# 279                                  dlf carlton estate
# 280                                 smart world orchard
# 281                               signature global park
# 282                        railway officers rpf society
# 283                                          godrej air
# 284                                emaar mgf palm hills
# 285                                        maruti vihar
# 286                                  vasant appartments
# 287                                    ansal heights 86
# 288                shapoorji pallonji joyville gurugram
# 289                                  puri the aravallis
# 290                                     the close north
# 291                                 smart world orchard
# 292                                emaar gurgaon greens
# 293                                  godrej nature plus
# 294                              landmark the residency
# 295                                         m3m capital
# 296                              emaar imperial gardens
# 297                                dlf belvedere towers
# 298                                           m3m crown
# 299                                              godrej
# 300                                central park resorts
# 301                                      tulip monsella
# 302             sare crescent parc royal greens phase 1
# 303                                aipl club residences
# 304                              experion the heartsong
# 305                               signature global city
# 306                              bestech park view city
# 307                                  emaar palm gardens
# 308                                          chd avenue
# 309                                          mvn athens
# 310                                   mahindra luminare
# 311                                     raheja navodaya
# 312                                  godrej nature plus
# 313                                          m3m urbana
# 314                              experion the heartsong
# 315                                          sobha city
# 316                                  godrej nature plus
# 317                                 smart world orchard
# 318                            emaar mgf the palm drive
# 319                         bestech park view residency
# 320                         bestech park view residency
# 321                                          m3m merlin
# 322                                    dlf the skycourt
# 323                                emaar gurgaon greens
# 324                                 afnhb jalvayu vihar
# 325                                    dlf regency park
# 326                                 ireo victory valley
# 327                                  ambience creacions
# 328                            signature global city 92
# 329        the khushboo cooperative housing society ltd
# 330                             adani m2k oyster grande
# 331                                dlf belvedere towers
# 332                                          sobha city
# 333                                     raheja vedaanta
# 334                                    dlf the skycourt
# 335                               suncity vatsal valley
# 336                                         m3m capital
# 337                              dlf city plots phase 3
# 338                                      bestech altura
# 339                             indiabulls centrum park
# 340                           orris aster court premier
# 341                                      paras quartier
# 342                                   mapsko casa bella
# 343                            samadhan shri kamal cghs
# 344                                     ambience lagoon
# 345                                       orchid petals
# 346                                   friends apartment
# 347                                     the close south
# 348                                          hero homes
# 349                         bestech park view residency
# 350                                          sobha city
# 351                         bestech park view residency
# 352                                    dlf the skycourt
# 353                                emaar gurgaon greens
# 354                shapoorji pallonji joyville gurugram
# 355                                    dlf regency park
# 356                                     eldeco accolade
# 357                                          bptp terra
# 358                                         ss the leaf
# 359                                 ireo victory valley
# 360                                     emaar digihomes
# 361                                 ireo victory valley
# 362                                    dlf regency park
# 363                    emaar mgf emerald floors premier
# 364                             indiabulls centrum park
# 365                           orris carnation residency
# 366                         sbr minda sec 1 imt manesar
# 367                                      dlf the ultima
# 368                                         m3m capital
# 369                                          bptp terra
# 370                                   indiabulls enigma
# 371                                      the lions cghs
# 372                                      m3m golfestate
# 373                            emaar mgf the palm drive
# 374                                 afnhb jalvayu vihar
# 375                                 experion windchants
# 376                                 experion windchants
# 377                                 experion windchants
# 378                                    antriksh heights
# 379                                          sobha city
# 380                            unitech uniworld gardens
# 381                                park royal apartment
# 382                               elan the presidential
# 383                                      raheja atharva
# 384                                   indiabulls enigma
# 385                                central park resorts
# 386                          central park flower valley
# 387                         bestech park view residency
# 388                                emaar gurgaon greens
# 389                            emaar mgf the palm drive
# 390                                emaar gurgaon greens
# 391                    emaar mgf emerald floors premier
# 392                                 mapsko royale ville
# 393                    emaar mgf emerald floors premier
# 394                                      ats tourmaline
# 395                        railway officers rpf society
# 396                                     emaar digihomes
# 397                                  emaar palm gardens
# 398                                          tarc maceo
# 399                    emaar mgf emerald floors premier
# 400                              pioneer urban presidia
# 401                                emaar mgf palm hills
# 402                    emaar mgf emerald floors premier
# 403                                           la lagune
# 404                                          m3m merlin
# 405                                        m3m latitude
# 406                                         m3m skywalk
# 407                                      dlf the primus
# 408                                      dlf the primus
# 409                                   dlf regal gardens
# 410                                          paras dews
# 411                                        pioneer park
# 412                                         ss the leaf
# 413                                          chd avenue
# 414                                          ireo skyon
# 415                                       tata primanti
# 416                             la vida by tata housing
# 417                                   dlf regal gardens
# 418                            bestech park view ananda
# 419                                        tulip purple
# 420                             indiabulls centrum park
# 421                                       sbtl caladium
# 422                              vatika the seven lamps
# 423                                          ireo skyon
# 424                           orris carnation residency
# 425                                emaar gurgaon greens
# 426                         bestech park view residency
# 427                                       m3m woodshire
# 428                                  ambience creacions
# 429                             indiabulls centrum park
# 430                            pareena coban residences
# 431                               parsvnath green ville
# 432                            emaar mgf the palm drive
# 433                              conscient heritage max
# 434                            emaar mgf emerald estate
# 435                                   dlf regal gardens
# 436                                 ireo victory valley
# 437                                          m3m merlin
# 438                                          m3m merlin
# 439                         bestech park view residency
# 440                                         m3m skywalk
# 441                                         m3m skywalk
# 442                                         m3m skywalk
# 443                                    puri emerald bay
# 444                                         ss the leaf
# 445                                         ss the leaf
# 446                                         ss the leaf
# 447                                         ss the leaf
# 448                                         ss the leaf
# 449                                         m3m skywalk
# 450                          ansal api celebrity suites
# 451                              cghs airport apartment
# 452                         sbr minda sec-1 imt manesar
# 453                                   prasha apartments
# 454                                      m3m golfestate
# 455                                 experion windchants
# 456                                 experion windchants
# 457                                emaar gurgaon greens
# 458                                 experion windchants
# 459                                   indiabulls enigma
# 460                                   indiabulls enigma
# 461                                          ireo skyon
# 462                                       tata primanti
# 463                           vatika independent floors
# 464                                   citizen apartment
# 465                             adani m2k oyster grande
# 466                shapoorji pallonji joyville gurugram
# 467                shapoorji pallonji joyville gurugram
# 468                                emaar gurgaon greens
# 469                                     kiran residency
# 470                                      dlf the ultima
# 471                                      dlf the ultima
# 472                                      dlf the ultima
# 473                                    ss the coralwood
# 474                                      dlf the ultima
# 475                                       m3m woodshire
# 476                                    puri emerald bay
# 477                                       m3m woodshire
# 478                    emaar mgf emerald floors premier
# 479                                 eros wembley estate
# 480                         bestech park view residency
# 481                         bestech park view residency
# 482                         bestech park view residency
# 483                               alpha corp gurgaonone
# 484                                        deepak minda
# 485                             indiabulls centrum park
# 486                                  imperia the esfera
# 487                                         ss the leaf
# 488                            emaar mgf the palm drive
# 489                                  emaar palm gardens
# 490                                  emaar palm gardens
# 491                                          ireo skyon
# 492                                      dlf the ultima
# 493                                   dlf regal gardens
# 494                                         ss the leaf
# 495                                         ss the leaf
# 496                                         ss the leaf
# 497                                         ss the leaf
# 498                                         ss the leaf
# 499                           orris aster court premier
# 500                                          ireo skyon
# 501                                       tata primanti
# 502                                       tata primanti
# 503                                       tata primanti
# 504                                    antriksh heights
# 505                                    antriksh heights
# 506                             shree vardhman victoria
# 507                         bestech park view grand spa
# 508                            bestech park view ananda
# 509                                 mapsko royale ville
# 510                                     the close north
# 511                          bestech park view spa next
# 512                                      vatika gurgaon
# 513                                          m3m merlin
# 514                                        m3m latitude
# 515                                emaar gurgaon greens
# 516                                umang monsoon breeze
# 517                                umang monsoon breeze
# 518                                  emaar palm gardens
# 519                               bestech spa signature
# 520                         bestech park view grand spa
# 521                                      dlf the ultima
# 522                                      dlf the ultima
# 523                                      dlf the ultima
# 524                         bestech park view sanskruti
# 525                               bestech spa signature
# 526                                  swarn jayanti cghs
# 527                             aipl the peaceful homes
# 528                                  ambience creacions
# 529                                      m3m the marina
# 530                                          chd avenue
# 531                             signature global solera
# 532                             signature global solera
# 533                                  emaar palm heights
# 534                                emaar mgf palm hills
# 535                                    dlf the skycourt
# 536                             la vida by tata housing
# 537                            emaar mgf the palm drive
# 538                                   parsvnath exotica
# 539                             shree arihant apartment
# 540                             la vida by tata housing
# 541                                       mahindra aura
# 542                             aipl the peaceful homes
# 543                                      vatika gurgaon
# 544                                      vatika gurgaon
# 545                              krrish provence estate
# 546                                         godrej aria
# 547                             sare green parc phase 3
# 548                                 ireo victory valley
# 549                                dlf new town heights
# 550                                dlf new town heights
# 551                                dlf new town heights
# 552                                   dlf regal gardens
# 553                                   dlf regal gardens
# 554                                   dlf regal gardens
# 555                                     the close north
# 556                                          bptp terra
# 557                                 experion windchants
# 558                    emaar mgf emerald floors premier
# 559                                          m3m merlin
# 560                                  emaar palm gardens
# 561                           shri banke bihari society
# 562                                     kiran residency
# 563                                     ambience lagoon
# 564                              vatika the seven lamps
# 565                shapoorji pallonji joyville gurugram
# 566                         bestech park view grand spa
# 567                                      m3m golfestate
# 568                                  imperia the esfera
# 569                                dlf new town heights
# 570                         bestech park view grand spa
# 571                                 ireo victory valley
# 572                                         m3m skywalk
# 573                                dlf new town heights
# 574                                dlf new town heights
# 575                                   dlf regal gardens
# 576                                      dlf the primus
# 577                         ansal housing highland park
# 578                              bestech park view city
# 579                              conscient heritage max
# 580                                    dlf regency park
# 581                                              godrej
# 582                             adani m2k oyster grande
# 583                                    dlf regency park
# 584                                          ats kocoon
# 585                              experion the heartsong
# 586                                      ats tourmaline
# 587                                   orris aster court
# 588                                 ireo victory valley
# 589                                        pioneer park
# 590                               alpha corp gurgaonone
# 591                                         godrej icon
# 592                            emaar mgf emerald estate
# 593                                      vatika gurgaon
# 594                                  emaar palm heights
# 595                                      vatika gurgaon
# 596                                    green campus chs
# 597                                    green campus chs
# 598                                    puri emerald bay
# 599                                    puri emerald bay
# 600                                   indiabulls enigma
# 601                         bestech park view sanskruti
# 602                                 ireo victory valley
# 603                          bestech park view spa next
# 604                          bestech park view spa next
# 605                                      dlf the ultima
# 606                                      dlf the ultima
# 607                                  ambience creacions
# 608                                         tulip ivory
# 609                                          ireo skyon
# 610                                  ambience creacions
# 611                                      m3m golfestate
# 612                                  umang winter hills
# 613                                  mapsko mount ville
# 614                                              godrej
# 615                                  mapsko mount ville
# 616                                        city heights
# 617                                      kw royal court
# 618                             shree vardhman victoria
# 619                               alpha corp gurgaonone
# 620                              cghs airport apartment
# 621                                       gls avenue 51
# 622                                       kamroon court
# 623                          bestech park view spa next
# 624                            unitech uniworld gardens
# 625                                       tata primanti
# 626                                          chd avenue
# 627                                shree vardhman flora
# 628                              krrish provence estate
# 629                                       dlf the crest
# 630                                   dlf regal gardens
# 631                                   dlf regal gardens
# 632                                      m3m golfestate
# 633                              bestech park view city
# 634                                    dlf the skycourt
# 635                                      dlf the ultima
# 636                                  emaar palm gardens
# 637                              experion the heartsong
# 638                shapoorji pallonji joyville gurugram
# 639                           orris aster court premier
# 640                           orris aster court premier
# 641                           orris aster court premier
# 642                                shree vardhman flora
# 643                           orris carnation residency
# 644                                       saan verdante
# 645                                        tulip violet
# 646                                    puri emerald bay
# 647                                emaar gurgaon greens
# 648                                          ats kocoon
# 649                                    puri emerald bay
# 650                                   vatika city homes
# 651                              experion the heartsong
# 652                              pioneer urban presidia
# 653                                          paras dews
# 654                                          paras dews
# 655                             la vida by tata housing
# 656                           shri banke bihari society
# 657                             indiabulls centrum park
# 658                                          sobha city
# 659                                          m3m merlin
# 660                                          m3m merlin
# 661                                          ats kocoon
# 662                shapoorji pallonji joyville gurugram
# 663                              puri diplomatic greens
# 664                                   indiabulls enigma
# 665                                         ats triumph
# 666                                         ats triumph
# 667                                          paras dews
# 668                shapoorji pallonji joyville gurugram
# 669                              experion the heartsong
# 670                                          sobha city
# 671                                          sobha city
# 672                                       sbtl caladium
# 673                                         ats triumph
# 674                                       m3m woodshire
# 675                             signature global solera
# 676                             signature global solera
# 677                             signature global solera
# 678                             signature global solera
# 679                              experion the heartsong
# 680                                       m3m woodshire
# 681                                emaar gurgaon greens
# 682                            pareena coban residences
# 683                                  ireo the corridors
# 684                                        tulip violet
# 685                                      dlf the primus
# 686                                 experion windchants
# 687                         ansal housing highland park
# 688                                       m3m woodshire
# 689                                       m3m woodshire
# 690                                       m3m woodshire
# 691                                        godrej oasis
# 692                                        godrej oasis
# 693                                 satya the hermitage
# 694                                      vatika gurgaon
# 695                                      vatika gurgaon
# 696                                     raheja vedaanta
# 697                              conscient heritage max
# 698                             shree arihant apartment
# 699                                        tulip violet
# 700                                         tulip white
# 701                       denso haryana housing society
# 702                           the nav manesar apartment
# 703                                          ireo skyon
# 704                                          ireo skyon
# 705                                  umang winter hills
# 706                                         ss the leaf
# 707                               alpha corp gurgaonone
# 708                                          m3m merlin
# 709                                          m3m merlin
# 710                                 ireo victory valley
# 711                                        dlf the icon
# 712                                          m3m merlin
# 713                                       ansal heights
# 714                             professors enclave cghs
# 715                                 ansal maple heights
# 716                                 ireo victory valley
# 717                                 ireo the grand arch
# 718                                         m3m skywalk
# 719                                      vatika gurgaon
# 720                                 experion windchants
# 721                              capital residences 360
# 722                              bestech park view city
# 723                             la vida by tata housing
# 724                                        tulip violet
# 725                         bestech park view grand spa
# 726                                      dlf the primus
# 727                             signature global synera
# 728                                      vatika gurgaon
# 729                               alpha corp gurgaonone
# 730                               alpha corp gurgaonone
# 731                                   parsvnath exotica
# 732                                          sare homes
# 733                                          sare homes
# 734                                      vatika gurgaon
# 735                                      m3m golfestate
# 736                                    dlf the skycourt
# 737                                 emaar emerald hills
# 738                                     mapsko paradise
# 739                                          bptp terra
# 740                             adani m2k oyster grande
# 741                              emaar imperial gardens
# 742                                      unitech fresco
# 743                                ansal maple crescent
# 744                                       prime habitat
# 745                                dlf new town heights
# 746                                dlf new town heights
# 747                                         ss the leaf
# 748                                         ss the leaf
# 749                                       m3m woodshire
# 750                                   indiabulls enigma
# 751                shapoorji pallonji joyville gurugram
# 752                              puri diplomatic greens
# 753                                    dlf regency park
# 754                            emaar mgf the palm drive
# 755                                     eldeco accolade
# 756                                     eldeco accolade
# 757                             la vida by tata housing
# 758                             la vida by tata housing
# 759                            pareena coban residences
# 760                            pareena coban residences
# 761                            pareena coban residences
# 762                                tata gurgaon gateway
# 763                                tata gurgaon gateway
# 764                                tata gurgaon gateway
# 765                                          ats kocoon
# 766                shapoorji pallonji joyville gurugram
# 767                              conscient heritage max
# 768                              puri diplomatic greens
# 769                             la vida by tata housing
# 770                                          sobha city
# 771                                          sobha city
# 772                                       m3m woodshire
# 773                                      ats tourmaline
# 774                                      ats tourmaline
# 775                                      ats tourmaline
# 776                                       sbtl caladium
# 777                                        tulip violet
# 778                                        tulip violet
# 779                                        tulip violet
# 780                                        tulip violet
# 781                                        tulip violet
# 782                                        tulip violet
# 783                                      dlf the ultima
# 784                                      dlf the ultima
# 785                                          ats kocoon
# 786                                       sbtl caladium
# 787                                       sbtl caladium
# 788                                      m3m golfestate
# 789                             shree arihant apartment
# 790                                         m3m skywalk
# 791                                      the lions cghs
# 792                                sunischit apartments
# 793                                  emaar palm gardens
# 794                    emaar mgf emerald floors premier
# 795                                      dlf the ultima
# 796                                  emaar palm gardens
# 797                                umang monsoon breeze
# 798                                  emaar palm gardens
# 799                                          bptp terra
# 800                                         m3m skywalk
# 801                                          chd avenue
# 802                                          chd avenue
# 803                                          chd avenue
# 804                                          chd avenue
# 805                            bptp mansions park prime
# 806                                    dlf the skycourt
# 807                              bestech park view city
# 808                                hsiidc sidco aravali
# 809                                sunischit apartments
# 810                shapoorji pallonji joyville gurugram
# 811                shapoorji pallonji joyville gurugram
# ...
# 3597                                                                                                                                                                                                                                                                                                                                                                                                                                     ['Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'High Ceiling Height', 'Maintenance Staff', 'False Ceiling Lighting', 'Water Storage', 'No open drainage around', 'Visitor Parking', 'Park', 'Security Personnel', 'Low Density Society', 'Waste Disposal', 'Rain Water Harvesting']
# 3598                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ['Private Garden / Terrace', 'Maintenance Staff', 'Water Storage', 'Park', 'Visitor Parking', 'Waste Disposal', 'Rain Water Harvesting']
# 3599                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ['Private Garden / Terrace', 'Maintenance Staff', 'Water Storage', 'Park', 'Visitor Parking', 'Waste Disposal', 'Rain Water Harvesting']
# 3600                                                                                                                                                                                                                           ['Security / Fire Alarm', 'Feng Shui / Vaastu Compliant', 'Centrally Air Conditioned', 'Water purifier', 'High Ceiling Height', 'Maintenance Staff', 'Water Storage', 'Separate entry for servant room', 'No open drainage around', 'Piped-gas', 'Visitor Parking', 'Swimming Pool', 'Park', 'Security Personnel', 'Natural Light', 'Internet/wi-fi connectivity', 'Airy Rooms', 'Low Density Society', 'Fitness Centre / GYM', 'Waste Disposal', 'Rain Water Harvesting', 'Club house / Community Center']
# 3601                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ['Private Garden / Terrace', 'Maintenance Staff', 'Water Storage', 'Club house / Community Center']
# 3602                                                                                                                                                                                                                                                                                                                                                                                                           ['Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'High Ceiling Height', 'Maintenance Staff', 'False Ceiling Lighting', 'Water Storage', 'Separate entry for servant room', 'No open drainage around', 'Piped-gas', 'Visitor Parking', 'Park', 'Low Density Society', 'Waste Disposal', 'Rain Water Harvesting']
# 3603                                                                                                                                                 ['Water purifier', 'Centrally Air Conditioned', 'Security / Fire Alarm', 'Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'High Ceiling Height', 'Maintenance Staff', 'False Ceiling Lighting', 'Water Storage', 'Separate entry for servant room', 'No open drainage around', 'Bank Attached Property', 'Piped-gas', 'Internet/wi-fi connectivity', 'Recently Renovated', 'Visitor Parking', 'Park', 'Security Personnel', 'Natural Light', 'Airy Rooms', 'Spacious Interiors', 'Low Density Society', 'Waste Disposal', 'Rain Water Harvesting', 'Fitness Centre / GYM']
# 3604                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['High Ceiling Height', 'False Ceiling Lighting', 'Water Storage', 'No open drainage around', 'Park', 'Recently Renovated', 'Visitor Parking', 'Natural Light']
# 3605                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['High Ceiling Height', 'False Ceiling Lighting', 'Water Storage', 'Separate entry for servant room', 'No open drainage around', 'Park', 'Recently Renovated', 'Visitor Parking', 'Natural Light', 'Airy Rooms']
# 3606                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ['Feng Shui / Vaastu Compliant', 'High Ceiling Height', 'False Ceiling Lighting', 'Water Storage', 'No open drainage around', 'Park', 'Natural Light', 'Airy Rooms', 'Rain Water Harvesting']
# 3607                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'High Ceiling Height', 'False Ceiling Lighting', 'Water Storage', 'No open drainage around', 'Park', 'Natural Light', 'Internet/wi-fi connectivity', 'Airy Rooms']
# 3608                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['Feng Shui / Vaastu Compliant', 'High Ceiling Height', 'False Ceiling Lighting', 'Water Storage', 'No open drainage around', 'Park', 'Natural Light', 'Internet/wi-fi connectivity', 'Rain Water Harvesting']
# 3609                                                                                                                                                                                                                                                                                                                                                                                                                                    ['Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'High Ceiling Height', 'False Ceiling Lighting', 'Water Storage', 'Separate entry for servant room', 'No open drainage around', 'Piped-gas', 'Visitor Parking', 'Park', 'Natural Light', 'Internet/wi-fi connectivity', 'Airy Rooms']
# 3610                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ['Private Garden / Terrace', 'High Ceiling Height', 'False Ceiling Lighting', 'Water Storage', 'No open drainage around', 'Visitor Parking', 'Natural Light', 'Internet/wi-fi connectivity', 'Airy Rooms', 'Rain Water Harvesting']
# 3611                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ['Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'High Ceiling Height', 'False Ceiling Lighting', 'Separate entry for servant room', 'Visitor Parking', 'Natural Light', 'Internet/wi-fi connectivity', 'Airy Rooms', 'Rain Water Harvesting']
# 3612                                                                                                                                                                                                                                                                                                                                                                                                                                                                ['Private Garden / Terrace', 'High Ceiling Height', 'False Ceiling Lighting', 'Water Storage', 'Separate entry for servant room', 'No open drainage around', 'Visitor Parking', 'Natural Light', 'Internet/wi-fi connectivity', 'Airy Rooms', 'Rain Water Harvesting']
# 3613                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['High Ceiling Height', 'False Ceiling Lighting', 'Water Storage', 'Separate entry for servant room', 'Park', 'Recently Renovated', 'Natural Light', 'Internet/wi-fi connectivity', 'Rain Water Harvesting']
# 3614                                                                                                                                                                                                                                                                                                                                           ['Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'High Ceiling Height', 'Maintenance Staff', 'Water Storage', 'Separate entry for servant room', 'No open drainage around', 'Bank Attached Property', 'Visitor Parking', 'Park', 'Security Personnel', 'Internet/wi-fi connectivity', 'Low Density Society', 'Fitness Centre / GYM', 'Waste Disposal', 'Rain Water Harvesting']
# 3615                                                                                                                                                                                                                                                                                                                                                                                                                          ['Feng Shui / Vaastu Compliant', 'High Ceiling Height', 'Maintenance Staff', 'False Ceiling Lighting', 'Water Storage', 'Separate entry for servant room', 'No open drainage around', 'Bank Attached Property', 'Visitor Parking', 'Park', 'Low Density Society', 'Waste Disposal', 'Rain Water Harvesting']
# 3616                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['High Ceiling Height', 'Maintenance Staff', 'Water Storage', 'Visitor Parking', 'Waste Disposal', 'Rain Water Harvesting']
# 3617                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ['Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'High Ceiling Height', 'Maintenance Staff', 'False Ceiling Lighting', 'Water Storage', 'Park', 'Visitor Parking', 'Internet/wi-fi connectivity', 'Waste Disposal', 'Rain Water Harvesting']
# 3618                                                                                                                                                                                                                                                                                                                                                                                                                                                                ['Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'High Ceiling Height', 'Maintenance Staff', 'False Ceiling Lighting', 'Water Storage', 'Park', 'Visitor Parking', 'Security Personnel', 'Low Density Society', 'Waste Disposal', 'Rain Water Harvesting']

# %%
df['features'].isnull().sum()
# Out:
# 575

# %%
import pandas as pd
app_df = pd.read_csv('../CSV Files/appartments.csv')
app_df.head(2)
# Out:
#          PropertyName                               PropertySubName  \
# 0  Smartworld One DXP  2, 3, 4 BHK Apartment in Sector 113, Gurgaon
# 1           M3M Crown     3, 4 BHK Apartment in Sector 111, Gurgaon
#
#                                                                                                                                   NearbyLocations  \
# 0                                           ['Bajghera Road', 'Palam Vihar Halt', 'DPSG Palam Vihar', 'Park Hospital', 'Gurgaon Railway Station']
# 1  ['DPSG Palam Vihar Gurugram', 'The NorthCap University', 'Park Hospital, Palam Vihar', 'Pacific D21 Mall', 'Palam Vihar Halt Railway Station']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     LocationAdvantages  \
# 0         {'Bajghera Road': '800 Meter', 'Palam Vihar Halt': '2.5 KM', 'DPSG Palam Vihar': '3.1 KM', 'Park Hospital': '3.1 KM', 'Gurgaon Railway Station': '4.9 KM', 'The NorthCap University': '5.4 KM', 'Dwarka Expy': '1.2 KM', 'Hyatt Place Gurgaon Udyog Vihar': '7.7 KM', 'Dwarka Sector 21, Metro Station': '7.2 KM', 'Pacific D21 Mall': '7.4 KM', 'Indira Gandhi International Airport': '14.7 KM', 'Hamoni Golf Camp': '6.2 KM', 'Fun N Food Waterpark': '8.8 KM', 'Accenture DDC5': '9 KM'}
# 1  {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The NorthCap University': '4.4 Km', 'Park Hospital, Palam Vihar': '1.4 Km', 'Pacific D21 Mall': '8.2 Km', 'Palam Vihar Halt Railway Station': '1.2 Km', 'Dwarka Sector 21 Metro Station': '8.1 Km', 'Dwarka Expressway': '450 m', 'Fun N Food Water Park': '8.1 Km', 'Indira Gandhi International Airport': '14.1 Km', 'Tau DeviLal Sports Complex': '11.2 Km', 'Hamoni Golf Camp': '5 Km', 'Hyatt Place': '6.1 Km', 'Altrade Business Centre': '11.2 Km'}
#
#                                                                           Link  \
# 0  https://www.99acres.com/smartworld-one-dxp-sector-113-gurgaon-npxid-r400415
# 1           https://www.99acres.com/m3m-crown-sector-111-gurgaon-npxid-r404068
#
#                                                                                                                                                                                                                                                                                                                                                                                            PriceDetails  \
# 0  {'2 BHK': {'building_type': 'Apartment', 'area_type': 'Carpet Area', 'area': '1,370 sq.ft.', 'price-range': '₹ 2 - 2.4 Cr'}, '3 BHK': {'building_type': 'Apartment', 'area_type': 'Carpet Area', 'area': '1,850 - 2,050 sq.ft.', 'price-range': '₹ 2.25 - 3.59 Cr'}, '4 BHK': {'building_type': 'Apartment', 'area_type': 'Carpet Area', 'area': '2,600 sq.ft.', 'price-range': '₹ 3.24 - 4.56 Cr'}}
# 1                                                                                                       {'3 BHK': {'building_type': 'Apartment', 'area_type': 'Super Built-up Area', 'area': '1,605 - 2,170 sq.ft.', 'price-range': '₹ 2.2 - 3.03 Cr'}, '4 BHK': {'building_type': 'Apartment', 'area_type': 'Super Built-up Area', 'area': '2,248 - 2,670 sq.ft.', 'price-range': '₹ 3.08 - 3.73 Cr'}}
#
#                                                                                                                                    TopFacilities
# 0                     ['Swimming Pool', 'Salon', 'Restaurant', 'Spa', 'Cafeteria', 'Sun Deck', '24x7 Security', 'Club House', 'Gated Community']
# 1  ['Bowling Alley', 'Mini Theatre', 'Manicured Garden', 'Swimming Pool', 'Flower Garden', 'Reading Lounge', 'Golf Course', 'Barbecue', 'Sauna']

# %%
app_df['PropertyName'] = app_df['PropertyName'].str.lower()

# %%
temp_df = df[df['features'].isnull()]

# %%
temp_df.shape
# Out:
# (575, 26)

# %%
x = temp_df.merge(app_df,left_on='society',right_on='PropertyName',how='left')['TopFacilities']

# %%
df.loc[temp_df.index,'features'] = x.values

# %%
df['features'].isnull().sum()
# Out:
# 438

# %%
from sklearn.preprocessing import MultiLabelBinarizer
import ast

# %%
features_list = []

for item in df['features']:
    
    if pd.notnull(item) and item.startswith('['):
        features_list.append(ast.literal_eval(item))
    else:
        features_list.append([])

df['features_list'] = features_list
mlb = MultiLabelBinarizer()
features_binary_matrix = mlb.fit_transform(df['features_list'])
features_binary_df = pd.DataFrame(features_binary_matrix,columns=mlb.classes_)

# %%
features_binary_df.sample(5)
# Out:
#       24/7 Power Backup  24/7 Water Supply  24x7 Security  ATM  \
# 3206                  0                  0              0    0
# 2567                  0                  0              0    0
# 1219                  0                  0              0    0
# 2174                  0                  0              0    0
# 2721                  0                  0              0    0
#
#       Aerobics Centre  Air Hockey  Airy Rooms  Amphitheatre  \
# 3206                0           0           0             0
# 2567                0           0           1             0
# 1219                0           0           1             0
# 2174                0           0           0             0
# 2721                0           0           0             0
#
#       Automated Car Wash  Badminton Court  Bank Attached Property  \
# 3206                   0                0                       0
# 2567                   0                0                       0
# 1219                   0                0                       1
# 2174                   0                0                       0
# 2721                   0                0                       0
#
#       Banquet Hall  Bar/Chill-Out Lounge  Barbecue  Basketball Court  \
# 3206             0                     0         0                 0
# 2567             0                     0         0                 0
# 1219             0                     0         0                 0
# 2174             0                     0         0                 0
# 2721             0                     0         0                 0
#
#       Beach Volley Ball Court  Billiards  Bowling Alley  Bus Shelter  \
# 3206                        0          0              0            0
# 2567                        0          0              0            0
# 1219                        0          0              0            0
# 2174                        0          0              0            0
# 2721                        0          0              0            0
#
#       Business Lounge  CCTV Camera Security  Cafeteria  Car Parking  \
# 3206                0                     0          0            0
# 2567                0                     0          0            0
# 1219                0                     0          0            0
# 2174                0                     0          0            0
# 2721                0                     0          0            0
#
#       Car wash area  Card Room  Centrally Air Conditioned  Changing Area  \
# 3206              0          0                          0              0
# 2567              0          0                          0              0
# 1219              0          0                          1              0
# 2174              0          0                          0              0
# 2721              0          0                          0              0
#
#       Children's Play Area  Cigar Lounge  Clinic  Club House  \
# 3206                     0             0       0           0
# 2567                     0             0       0           0
# 1219                     0             0       0           0
# 2174                     0             0       0           0
# 2721                     0             0       0           0
#
#       Club house / Community Center  Community Hall  Concierge Service  \
# 3206                              0               0                  0
# 2567                              1               0                  0
# 1219                              1               0                  0
# 2174                              0               0                  0
# 2721                              1               0                  0
#
#       Conference room  Creche/Day care  Cricket Pitch  Doctor on Call  \
# 3206                0                0              0               0
# 2567                0                0              0               0
# 1219                0                0              0               0
# 2174                0                0              0               0
# 2721                0                0              0               0
#
#       Earthquake Resistant  Entrance Lobby  False Ceiling Lighting  \
# 3206                     0               0                       0
# 2567                     0               0                       0
# 1219                     0               0                       1
# 2174                     0               0                       0
# 2721                     0               0                       0
#
#       Feng Shui / Vaastu Compliant  Fitness Centre / GYM  Flower Garden  \
# 3206                             0                     0              0
# 2567                             0                     1              0
# 1219                             1                     1              0
# 2174                             0                     0              0
# 2721                             1                     1              0
#
#       Food Court  Foosball  Football  Fountain  Gated Community  Gazebo  \
# 3206           0         0         0         0                0       0
# 2567           0         0         0         0                0       0
# 1219           0         0         0         0                0       0
# 2174           0         0         0         0                0       0
# 2721           0         0         0         0                0       0
#
#       Golf Course  Grocery Shop  Gymnasium  High Ceiling Height  \
# 3206            0             0          0                    0
# 2567            0             0          0                    1
# 1219            0             0          0                    1
# 2174            0             0          0                    0
# 2721            0             0          0                    0
#
#       High Speed Elevators  Infinity Pool  Intercom Facility  \
# 3206                     0              0                  0
# 2567                     0              0                  0
# 1219                     0              0                  1
# 2174                     0              0                  0
# 2721                     0              0                  1
#
#       Internet/wi-fi connectivity  Jacuzzi  Jogging Track  Landscape Garden  \
# 3206                            0        0              0                 0
# 2567                            1        0              0                 0
# 1219                            1        0              0                 0
# 2174                            0        0              0                 0
# 2721                            0        0              0                 0
#
#       Laundry  Lawn Tennis Court  Library  Lift(s)  Lounge  \
# 3206        0                  0        0        0       0
# 2567        0                  0        0        1       0
# 1219        0                  0        0        1       0
# 2174        0                  0        0        0       0
# 2721        0                  0        0        1       0
#
#       Low Density Society  Maintenance Staff  Manicured Garden  \
# 3206                    0                  0                 0
# 2567                    0                  1                 0
# 1219                    1                  1                 0
# 2174                    0                  0                 0
# 2721                    0                  1                 0
#
#       Medical Centre  Milk Booth  Mini Theatre  Multipurpose Court  \
# 3206               0           0             0                   0
# 2567               0           0             0                   0
# 1219               0           0             0                   0
# 2174               0           0             0                   0
# 2721               0           0             0                   0
#
#       Multipurpose Hall  Natural Light  Natural Pond  No open drainage around  \
# 3206                  0              0             0                        0
# 2567                  0              1             0                        0
# 1219                  0              1             0                        1
# 2174                  0              0             0                        0
# 2721                  0              0             0                        0
#
#       Park  Party Lawn  Pergola  Piped Gas  Piped-gas  Pool Table  \
# 3206     0           0        0          0          0           0
# 2567     1           0        0          0          0           0
# 1219     1           0        0          0          1           0
# 2174     0           0        0          0          0           0
# 2721     1           0        0          0          0           0
#
#       Power Back up Lift  Power Back-up  Private Garden / Terrace  \
# 3206                   0              0                         0
# 2567                   0              0                         0
# 1219                   0              0                         1
# 2174                   0              0                         0
# 2721                   0              0                         0
#
#       Property Staff  RO System  Rain Water Harvesting  Reading Lounge  \
# 3206               0          0                      0               0
# 2567               0          0                      0               0
# 1219               0          0                      1               0
# 2174               0          0                      0               0
# 2721               0          0                      0               0
#
#       Recently Renovated  Reflexology Park  Restaurant  Salon  Sauna  School  \
# 3206                   0                 0           0      0      0       0
# 2567                   0                 0           0      0      0       0
# 1219                   1                 0           0      0      0       0
# 2174                   0                 0           0      0      0       0
# 2721                   0                 0           0      0      0       0
#
#       Security / Fire Alarm  Security Personnel  \
# 3206                      0                   0
# 2567                      1                   1
# 1219                      1                   1
# 2174                      0                   0
# 2721                      1                   0
#
#       Separate entry for servant room  Sewage Treatment Plant  \
# 3206                                0                       0
# 2567                                0                       0
# 1219                                1                       0
# 2174                                0                       0
# 2721                                0                       0
#
#       Shopping Centre  Skating Rink  Solar Lighting  Solar Water Heating  Spa  \
# 3206                0             0               0                    0    0
# 2567                0             0               0                    0    0
# 1219                1             0               0                    0    0
# 2174                0             0               0                    0    0
# 2721                1             0               0                    0    0
#
#       Spacious Interiors  Squash Court  Steam Room  Sun Deck  Swimming Pool  \
# 3206                   0             0           0         0              0
# 2567                   0             0           0         0              1
# 1219                   1             0           0         0              1
# 2174                   0             0           0         0              0
# 2721                   0             0           0         0              1
#
#       Temple  Terrace Garden  Theatre  Toddler Pool  Valet Parking  \
# 3206       0               0        0             0              0
# 2567       0               0        0             0              0
# 1219       0               0        0             0              0
# 2174       0               0        0             0              0
# 2721       0               0        0             0              0
#
#       Vastu Compliant  Video Door Security  Visitor Parking  Visitors Parking  \
# 3206                0                    0                1                 0
# 2567                0                    0                1                 0
# 1219                0                    0                1                 0
# 2174                0                    0                0                 0
# 2721                0                    0                1                 0
#
#       Volley Ball Court  Waiting Lounge  Waste Disposal  Water Softener Plant  \
# 3206                  0               0               0                     0
# 2567                  0               0               1                     0
# 1219                  0               0               1                     0
# 2174                  0               0               0                     0
# 2721                  0               0               0                     0
#
#       Water Storage  Water purifier  Water softening plant  \
# 3206              0               0                      0
# 2567              1               0                      0
# 1219              1               1                      1
# 2174              0               0                      0
# 2721              1               0                      0
#
#       Wi-Fi Connectivity  Yoga/Meditation Area
# 3206                   0                     0
# 2567                   0                     0
# 1219                   0                     0
# 2174                   0                     0
# 2721                   0                     0

# %%
weights = {
    '24/7 Power Backup': 8,
    '24/7 Water Supply': 4,
    '24x7 Security': 7,
    'ATM': 4,
    'Aerobics Centre': 6,
    'Airy Rooms': 8,
    'Amphitheatre': 7,
    'Badminton Court': 7,
    'Banquet Hall': 8,
    'Bar/Chill-Out Lounge': 9,
    'Barbecue': 7,
    'Basketball Court': 7,
    'Billiards': 7,
    'Bowling Alley': 8,
    'Business Lounge': 9,
    'CCTV Camera Security': 8,
    'Cafeteria': 6,
    'Car Parking': 6,
    'Card Room': 6,
    'Centrally Air Conditioned': 9,
    'Changing Area': 6,
    "Children's Play Area": 7,
    'Cigar Lounge': 9,
    'Clinic': 5,
    'Club House': 9,
    'Concierge Service': 9,
    'Conference room': 8,
    'Creche/Day care': 7,
    'Cricket Pitch': 7,
    'Doctor on Call': 6,
    'Earthquake Resistant': 5,
    'Entrance Lobby': 7,
    'False Ceiling Lighting': 6,
    'Feng Shui / Vaastu Compliant': 5,
    'Fire Fighting Systems': 8,
    'Fitness Centre / GYM': 8,
    'Flower Garden': 7,
    'Food Court': 6,
    'Foosball': 5,
    'Football': 7,
    'Fountain': 7,
    'Gated Community': 7,
    'Golf Course': 10,
    'Grocery Shop': 6,
    'Gymnasium': 8,
    'High Ceiling Height': 8,
    'High Speed Elevators': 8,
    'Infinity Pool': 9,
    'Intercom Facility': 7,
    'Internal Street Lights': 6,
    'Internet/wi-fi connectivity': 7,
    'Jacuzzi': 9,
    'Jogging Track': 7,
    'Landscape Garden': 8,
    'Laundry': 6,
    'Lawn Tennis Court': 8,
    'Library': 8,
    'Lounge': 8,
    'Low Density Society': 7,
    'Maintenance Staff': 6,
    'Manicured Garden': 7,
    'Medical Centre': 5,
    'Milk Booth': 4,
    'Mini Theatre': 9,
    'Multipurpose Court': 7,
    'Multipurpose Hall': 7,
    'Natural Light': 8,
    'Natural Pond': 7,
    'Park': 8,
    'Party Lawn': 8,
    'Piped Gas': 7,
    'Pool Table': 7,
    'Power Back up Lift': 8,
    'Private Garden / Terrace': 9,
    'Property Staff': 7,
    'RO System': 7,
    'Rain Water Harvesting': 7,
    'Reading Lounge': 8,
    'Restaurant': 8,
    'Salon': 8,
    'Sauna': 9,
    'Security / Fire Alarm': 9,
    'Security Personnel': 9,
    'Separate entry for servant room': 8,
    'Sewage Treatment Plant': 6,
    'Shopping Centre': 7,
    'Skating Rink': 7,
    'Solar Lighting': 6,
    'Solar Water Heating': 7,
    'Spa': 9,
    'Spacious Interiors': 9,
    'Squash Court': 8,
    'Steam Room': 9,
    'Sun Deck': 8,
    'Swimming Pool': 8,
    'Temple': 5,
    'Theatre': 9,
    'Toddler Pool': 7,
    'Valet Parking': 9,
    'Video Door Security': 9,
    'Visitor Parking': 7,
    'Water Softener Plant': 7,
    'Water Storage': 7,
    'Water purifier': 7,
    'Yoga/Meditation Area': 7
}
valid_cols = [col for col in weights if col in features_binary_df.columns]

luxury_score = (
    features_binary_df[valid_cols]
    .multiply([weights[col] for col in valid_cols])
    .sum(axis=1)
)

# %%
df['luxury_score'] = luxury_score

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6722.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
#   additionalRoom  floorNum facing       agePossession  \
# 0  not available       4.0   West      Relatively New
# 1  not available       1.0   West        Old Property
# 2  not available      12.0    NaN        New Property
# 3     study room       2.0    NaN      Relatively New
# 4     study room       5.0    NaN  Under Construction
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pearl Dental Clinic', 'Taneja Hospital', 'Dr. Ashok Jain', 'Dr. Madan Clinic', 'Geeta Nursing Home Gurgaon', 'Chiranjiv Hospital', 'Dev Man Kathuria Clinic', 'Aryan Hospital', 'Kr Dental Hub', 'Swastik Maternity and Medical Centre', 'Satyam Hospital Gurgaon', 'Ravi Clinic and Health Care Centre', 'D.R. Rajnis Gupta Clinic', 'Esic Hospital Gurugram', 'Gurgaon Eye Centre', 'Bindal Clinic', 'Shiv Mahima Patient Care Bureau', 'Shree Krishna Hospital Gurgaon', 'M.S Hospital', 'My Care Clinic', 'Ankur Clinic and Maternity Home', 'Triveni Hospital Gurgaon', 'Shri Gobind Hospital', 'Navjeevan Hospital and Maternity Centre', 'Lal Superspeciality Hospital', 'Sparsh Hospital Gurgaon', 'Prateek Nursing Home And Polyclinic', 'Jain Sant Phool Chand Ji Charitable Hospital', 'Sarvodya Hospital', 'Bhatnagar Maternity and Nursing Home', 'Tirath Ram Hospitals Pvt Ltd', 'Dr. Sarvejeet Singh', 'Centre For Sight Gurgaon New Railway Road', 'Dr. Ajay S. Gupta Clinic', 'Kidney Clinic', 'Mangalam Hospital and Heart Centre Gurgaon', 'Sethi Hospital Gurgaon', 'Shubham Hospital Gurgaon', 'Kharbanda Maternity and Nursing Home', 'Gupta Hospital Gurgaon', 'Dentecare - Multispeciality Dental Clinic', 'State bank of india', 'Hdfc bank', 'Kotak bank', 'Indian bank', 'Pizza Hut', 'St. Michaels Sr. Sec. School', 'Dronacharya Government College']
# 1                                                                                                                                                ['Chintapurni Mandir', 'Sheetla Mata Mandir', 'State bank ATM', 'Sneh Hospital Gurgaon', 'Jiya Clinic', 'Dr. Mittal Clinic', "Dr. Anurag's Child Care Clinic", 'Yashroop Medical Centre', 'Dr. Sindhu Clinic', 'Bhardwaj Hospital', 'Jain Sant Phool Chand Ji Charitable Hospital', 'Sarvodya Hospital', 'Dr. Hitesh Dawar', 'Prateek Nursing Home And Polyclinic', 'R K Hospital Gurgaon', 'Chirag Hospital Pvt. Ltd', 'Kr Dental Hub', 'Gurgaon Eye Centre', 'Shree Krishna Hospital Gurgaon', 'Dr. Ashok Jain', 'GH Gurgaon', 'Aryan Hospital', 'Dr. Agya Ram Sharma Clinic', 'Pearl Dental Clinic', 'D.R. Rajnis Gupta Clinic', 'Sparsh Hospital Gurgaon', 'Bhatnagar Maternity and Nursing Home', 'Geeta Nursing Home Gurgaon', 'Taneja Hospital', 'Ravi Clinic and Health Care Centre', 'Dr. Sarvejeet Singh', 'Esic Hospital Gurugram', 'Centre For Sight Gurgaon New Railway Road', 'Kidney Clinic', 'Jackson Hospital', 'Jeevan Jyoti Hospital Gurgaon', 'Chiranjiv Hospital', 'Dr. Tomar Clinic', 'Indian bank', 'Kotak bank', 'Hdfc bank', 'State bank of india', 'Pizza Hut', 'St. Michaels Sr. Sec. School', 'Lieutenant Atul Kataria School', 'Dronacharya Government College', 'Gurgaon railway station', 'Gurgaon railway station', 'Gurgaon railway station']
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['Huda City Metro', 'Golf Course extn road', 'Rajiv Chowk', 'IGI Airport', 'IMT Sohna', 'Damdama Lake']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ['Sector 55-56 Metro station', 'Bestech Central Square Mall', 'Golf Course Ext Road', 'Badshahpur Sohna Rd Hwy', 'ORCHIDS The International School', 'Sushant University', 'Marengo Asia Hospitals', 'Indira Gandhi Intl Airport', 'Gurgaon Railway Station']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. Sarkar Clinic', 'Sagar Clinic', 'Orris Community Center', 'Vijay Petrol Pump', 'HP Petrol Pump', 'Essar Petrol Pump', 'Indian Oil', 'Pizza Hut', 'KFC']
#
#                                                                                                                                                                                                                                                        furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 1       ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Geyser', '3 Light', '1 Curtains', '1 Chimney', '1 Modular Kitchen', 'No AC', 'No Bed', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 2                                                                                                                                                                                                                                                                 NaN
# 3                                                                                                                                                                                                                                                                 NaN
# 4                                                                                                                                                                                                                                                                  []
#
#                                                                                                                                                                                                                                                                                 features  \
# 0                                                                                                                                                                               ['Feng Shui / Vaastu Compliant', 'Security / Fire Alarm', 'Lift(s)', 'Water Storage', 'Visitor Parking']
# 1                                                                                                                                                                                             ['Security / Fire Alarm', 'Maintenance Staff', 'Water Storage', 'Park', 'Visitor Parking']
# 2                                                                                                                    ['Power Back-up', 'Feng Shui / Vaastu Compliant', 'Intercom Facility', 'Lift(s)', 'Swimming Pool', 'Park', 'Fitness Centre / GYM', 'Club house / Community Center']
# 3  ['Security / Fire Alarm', 'Private Garden / Terrace', 'Lift(s)', 'Maintenance Staff', 'False Ceiling Lighting', 'Water Storage', 'Visitor Parking', 'Swimming Pool', 'Natural Light', 'Airy Rooms', 'Fitness Centre / GYM', 'Club house / Community Center', 'Water softening plant']
# 4                                                                                                                                                                                                                                                                                    NaN
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        900.0           0             0
# 1                  NaN            NaN        650.0           0             0
# 2                  NaN            NaN        595.0           0             0
# 3                  NaN            NaN       1200.0           1             0
# 4               1345.0            NaN          NaN           1             0
#
#    store room  pooja room  others  furnishing_type  \
# 0           0           0       0                0
# 1           0           0       0                2
# 2           0           0       0                0
# 3           0           0       0                0
# 4           0           0       0                0
#
#                                                                                                                                                                                                                                                  features_list  \
# 0                                                                                                                                                               [Feng Shui / Vaastu Compliant, Security / Fire Alarm, Lift(s), Water Storage, Visitor Parking]
# 1                                                                                                                                                                             [Security / Fire Alarm, Maintenance Staff, Water Storage, Park, Visitor Parking]
# 2                                                                                                          [Power Back-up, Feng Shui / Vaastu Compliant, Intercom Facility, Lift(s), Swimming Pool, Park, Fitness Centre / GYM, Club house / Community Center]
# 3  [Security / Fire Alarm, Private Garden / Terrace, Lift(s), Maintenance Staff, False Ceiling Lighting, Water Storage, Visitor Parking, Swimming Pool, Natural Light, Airy Rooms, Fitness Centre / GYM, Club house / Community Center, Water softening plant]
# 4                                                                                                                                                                                                                                                           []
#
#    luxury_score
# 0            28
# 1            37
# 2            36
# 3            76
# 4             0

# %%
df.drop(columns=['nearbyLocations','furnishDetails','features','features_list','additionalRoom'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                      society      sector  price  \
# 487           flat                  ss the leaf   sector 85   1.09
# 2150          flat       puri diplomatic greens  sector 111   3.90
# 822           flat  bestech park view residency    sector 2   1.02
# 1225          flat       capital residences 360   sector 70   1.66
# 2708          flat                   rof ananda   sector 95   0.26
#
#       price_per_sqft    area  \
# 487           6666.0  1635.0
# 2150         13000.0  3000.0
# 822           7208.0  1415.0
# 1225          8400.0  1976.0
# 2708          6842.0   380.0
#
#                                                                                                                 areaWithType  \
# 487    Super Built up area 1640(152.36 sq.m.)Built Up area: 1638 sq.ft. (152.18 sq.m.)Carpet area: 1635 sq.ft. (151.9 sq.m.)
# 2150                                           Super Built up area 3000(278.71 sq.m.)Carpet area: 2950 sq.ft. (274.06 sq.m.)
# 822                                                                                   Super Built up area 1415(131.46 sq.m.)
# 1225  Super Built up area 1976(183.58 sq.m.)Built Up area: 1900 sq.ft. (176.52 sq.m.)Carpet area: 1500 sq.ft. (139.35 sq.m.)
# 2708                                                                                           Carpet area: 380 (35.3 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 487         2         2       3       9.0  South-West  Relatively New
# 2150        4         5      3+       6.0  North-East  Relatively New
# 822         2         2       3      11.0  South-West  Moderately Old
# 1225        3         3      3+       8.0        East    New Property
# 2708        1         1       1       8.0       North    New Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 487                1640.0         1638.0       1635.0           0
# 2150               3000.0            NaN       2950.0           0
# 822                1415.0            NaN          NaN           0
# 1225               1976.0         1900.0       1500.0           0
# 2708                  NaN            NaN        380.0           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 487              0           1           0       0                0
# 2150             1           0           0       0                1
# 822              0           0           0       0                0
# 1225             1           0           0       0                0
# 2708             0           0           0       0                0
#
#       luxury_score
# 487            174
# 2150           160
# 822             92
# 1225           132
# 2708            49

# %%
df.shape
# Out:
# (3619, 23)

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (3615, 23)

# %%
df.to_csv('../CSV Files/Gurgaon_properties_cleaned.csv',index=False)
