# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('../CSV Files/Gurgaon_properties_cleaned(1).csv')

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6722.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
# ...

# %%
df.shape
# Out:
# (3615, 23)

# %% [markdown]
# ## price

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (418,
#  count    418.000000
#  mean       9.183780
#  std        4.059181
#  min        5.400000
#  25%        6.410000
#  50%        8.000000
#  75%       10.557500
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 3530         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 3308         house                                        independent
# 3300         house                                        independent
# 3338         house                                     dlf city plots
# 3470         house                                   suncity township
# 3268         house                             emaar the palm springs
# 3456         house                                        independent
# 3284         house                                 vipul tatvam villa
# 3387         house                                        independent
# 3261         house                                     dlf city plots
# 2803         house                             luxury dlf city floors
# 3400         house                                        independent
# ...

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ## price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (351,
#  count       351.000000
#  mean      52680.415954
#  std       61406.044143
#  min       24366.000000
#  25%       28050.500000
#  50%       33333.000000
#  75%       41932.500000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft.sort_values('price_per_sqft',ascending=False).head(20)
# Out:
#      property_type                      society     sector  price  \
# 3268         house       emaar the palm springs  sector 54  24.00
# 3305         house       dlf city plots phase 2  sector 25  10.00
# 3055         house                  independent  sector 12   6.00
# 3227         house                        ansal  sector 43   1.85
# 3547         house               uppal southend  sector 49   6.75
# 3492         house  unitech nirvana birch court  sector 50   7.10
# 3564         house                  independent  sector 57   8.00
# 3317         house       dlf city plots phase 2  sector 25  10.50
# 3108         house          huda plot sector 38  sector 38   4.30
# 3280         house                  independent  sector 55   1.45
# 3362         house       unitech deerwood chase  sector 50   8.45
# 3527         house                  independent  sector 54   3.75
# 2961         house                  independent  sector 38   8.00
# ...

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      351.000000
# mean     29437.054131
# std      12309.639337
# min       2723.000000
# 25%      25549.500000
# 50%      29861.000000
# 75%      35648.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society      sector  price  \
# 2533          flat                unitech vistas   sector 70   9.00
# 2994         house                  malibu towne   sector 47   8.50
# 3144         house  project housing board colony   sector 31   8.00
# 3245         house            cloudnine cottages  sohna road   5.50
# 3260         house                   independent   sector 26  14.75
# 3268         house        emaar the palm springs   sector 54  24.00
# 3300         house                   independent   sector 26  26.00
# 3338         house                dlf city plots   sector 26  26.00
# 3421         house        emaar the palm springs   sector 54  14.00
# 3483         house            emaar mgf marbella   sector 66  18.00
# 3495         house                   independent   sector 25  16.00
# 3523         house                unitech escape   sector 50  10.80
# 3587         house                           nul   sector 28  12.50
#
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ## area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3585.000000
# mean       2958.996374
# std       23406.867388
# min         145.000000
# 25%        1264.000000
# 50%        1750.000000
# 75%        2338.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 109           flat      signature the roselia   sector 95   0.45
# 1262          flat            ramsons kshitij   sector 95   0.31
# 1919          flat  signature global solera 2  sector 107   0.51
# 2371          flat          hcbs sports ville  sohna road   0.35
# 3093         house                independent   sector 50   5.00
#
#       price_per_sqft      area                           areaWithType  \
# 109              7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 1262             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 1919             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 2371             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 3093           232.0  215517.0             Plot area 2(1011.71 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 109         2         2       2       2.0  South-West    New Property
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 3378         house                independent   sector 26  18.40
# 3065         house  ganpati heights apartment   sector 13   1.25
# 2268          flat                 rof ananda   sector 95   0.38
# 1264          flat                 rof ananda   sector 95   0.38
# 3134         house      dlf city plot phase 4   sector 28  13.00
# 78            flat              pyramid elite   sector 86   0.46
# 1263          flat                 rof ananda   sector 95   0.33
# 1385          flat      signature the serenas  sohna road   0.28
# 3295         house                independent   sector 25   7.30
# 1260          flat            ramsons kshitij   sector 95   0.24
# 1265          flat                 rof ananda   sector 95   0.21
# 2901         house                independent   sector 57   6.25
# 3353         house                independent   sector 43   5.50
# ...

# %%
df.drop(index=[3378,2268,1264,78,1263,1385,1260,1265,2894], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 3065         house  ganpati heights apartment   sector 13   1.25
# 3134         house      dlf city plot phase 4   sector 28  13.00
# 3295         house                independent   sector 25   7.30
# 2901         house                independent   sector 57   6.25
# 3353         house                independent   sector 43   5.50
# 2362          flat                 godrej air   sector 85   2.50
# 2908         house       unitech aspen greens   sector 50   6.95
# 2657          flat                godrej icon   sector 88   1.75
# 3308         house                independent   sector 43  27.50
# 1592          flat             m3m golfestate   sector 65  13.20
# 3247         house                independent  sohna road   5.50
#
#       price_per_sqft     area  \
# 3065           151.0  82781.0
# 3134          1992.0  65261.0
# 3295          1560.0  46795.0
# 2901          2778.0  22498.0
# ...

# %%
df.loc[3065,'area'] = 115*9
df.loc[3134,'area'] = 7250
df.loc[3295,'area'] = 5800
df.loc[2901,'area'] = 2660
df.loc[3353,'area'] = 2850
df.loc[2362,'area'] = 1812
df.loc[2908,'area'] = 2160
df.loc[2657,'area'] = 1175
df.loc[2657,'sector'] = 'sector 88a'

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3571.000000
# mean      1944.357603
# std       1205.116535
# min        145.000000
# 25%       1261.500000
# 50%       1745.000000
# 75%       2312.500000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ## bedRoom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\1737319938.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3571.000000
# mean        3.326799
# std         1.825867
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 2799         house                  independent   sector 54   5.00
# 2801         house                  independent   sector 43   4.50
# 3231         house                  independent   sector 17   3.87
# 2921         house                  independent   sector 17   3.93
# 3466         house                  independent   sector 54   5.50
# 2902         house                private house   sector 55   7.05
# 3484         house                  independent   sector 40  12.00
# 3446         house                  independent   sector 55   9.19
# 2835         house                  independent   sector 43  13.50
# 2837         house                  independent   sector 56  12.39
# 3261         house               dlf city plots   sector 26  20.00
# 2803         house       luxury dlf city floors   sector 26  20.00
# 2903         house                  independent   sector 11   4.50
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3527, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3527.000000
# mean        3.197051
# std         1.386472
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ## bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type      society     sector  price  price_per_sqft    area  \
# 3164         house  independent  sector 39    7.0         10000.0  7000.0
# 3212         house  independent  sector 24   11.0         28902.0  3806.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3164  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10        11
# 3212  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8        11
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 3164      3+       4.0  South-East  Relatively New                  NaN
# 3212      3+       3.0        East    Old Property                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 3164         7000.0          NaN           0             0           0
# 3212         5000.0          NaN           1             1           0
#
#       pooja room  others furnishing_type  luxury_score
# ...

# %% [markdown]
# ## super_built_up_area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1869.000000
# mean      1926.690503
# std        763.372694
# min         89.000000
# 25%       1480.000000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 628           flat       krrish provence estate  gwal pahari    7.5
# 1498          flat  bestech park view grand spa    sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 628           7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 1498          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 628         5         6      3+      23.0  North-East  Relatively New
# 1498        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 628               10000.0            NaN          NaN           0
# 1498               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others furnishing_type  \
# ...

# %% [markdown]
# ## built_up_area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 3308         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 3308  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 3308  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 3308          NaN           1             1           0           1       1
#
#      furnishing_type  luxury_score
# 3308   semifurnished            42

# %% [markdown]
# ## carpet_area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 1592          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
# 2362          flat      godrej air  sector 85    2.5          1379.0   1812.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1592  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 2362  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 1592       North  Moderately Old                  NaN            NaN
# 2362  North-East  Relatively New                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 1592      11000.0           0             1           0           0       0
# 2362      18122.0           1             0           0           1       1
#
#      furnishing_type  luxury_score
# ...

# %%
df.loc[2362,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 1592          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1592  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 1592  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 1592           0             1           0           0       0
#
#      furnishing_type  luxury_score
# 1592     unfurnished            60

# %%
df.head(3)
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6722.0
#
#     area                    areaWithType  bedRoom  bathroom balcony  floorNum  \
# 0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2       1       4.0
# 1  650.0  Carpet area: 650 (60.39 sq.m.)        2         2       1       1.0
# 2  595.0  Carpet area: 595 (55.28 sq.m.)        2         2       3      12.0
#
#   facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 0   West  Relatively New                  NaN            NaN        900.0
# 1   West    Old Property                  NaN            NaN        650.0
# 2    NaN    New Property                  NaN            NaN        595.0
#
# ...

# %% [markdown]
# ## luxury_score

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(x=df['luxury_score'])
# Out:
# <Axes: xlabel='luxury_score'>

# %%
df.shape
# Out:
# (3527, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6723.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 3189         house                   independent   sector 25   13.0
# 3224         house                   independent  sector 105    9.9
# 3294         house                dlf city plots   sector 26   19.0
# 3381         house                   independent   sector 28   12.0
# 3387         house                   independent   sector 26   20.0
# 3465         house                   independent   sector 26   19.0
# 3480         house  sushant lok 1 builder floors   sector 43   13.0
# 3494         house                   independent   sector 43    9.5
# 3595         house                   independent   sector 55    5.0
#
#       price_per_sqft    area  \
# 3189         45710.0  2844.0
# 3224         49500.0  2000.0
# 3294         42054.0  4518.0
# 3381         42194.0  2844.0
# 3387         44444.0  4500.0
# 3465         42222.0  4500.0
# 3480         48148.0  2700.0
# 3494         42222.0  2250.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# 250.5

# %%
df[(df['area']/df['bedRoom'])<250]
# Out:
#      property_type                  society      sector  price  \
# 115           flat    czar mahira homes 63a   sector 63   0.42
# 128           flat               mvn athens  sohna road   0.26
# 196           flat         supertech basera   sector 79   0.36
# 309           flat               mvn athens  sohna road   0.27
# 531           flat  signature global solera  sector 107   0.27
# ...            ...                      ...         ...    ...
# 3579         house            sector 38 rwa   sector 38   1.40
# 3589         house            sector 38 rwa   sector 38   4.30
# 3595         house              independent   sector 55   5.00
# 3598         house  iffco nagar and 17b rwa   sector 17   2.98
# 3599         house               huda floor   sector 38   4.00
#
#       price_per_sqft    area  \
# 115           7407.0   567.0
# 128           5394.0   482.0
# 196           7643.0   471.0
# 309           5895.0   458.0
# 531           5521.0   489.0
# ...

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
df[df['area_room_ratio']<250]['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     46
# 3     33
# 5     27
# 6     17
# 4     17
# 9     15
# 8     12
# 7      8
# 10     8
# Name: count, dtype: int64

# %%
df=df[df['area_room_ratio']>100]

# %%
outliers_df=df[(df['area_room_ratio']<250) & (df['bedRoom']>3)]

# %%
pd.set_option('display.max_rows', None)

# %%
outliers_df
# Out:
#      property_type                                 society      sector  price  \
# 2812         house                             independent   sector 38   2.10
# 2819         house                             independent   sector 25   7.60
# 2846         house                          uppal southend   sector 49   3.75
# 2914         house                             independent   sector 12   1.00
# 2923         house                             independent    sector 7   0.90
# 2925         house                               prem kunj  sohna road   0.50
# 2932         house                             independent     manesar   1.10
# 2934         house                             independent    sector 8   0.82
# 2938         house                    housing board colony   sector 28   3.50
# 2939         house                             independent     manesar   0.80
# 2940         house                             independent   sector 26   6.00
# ...

# %%
outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_26916\3359844150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)]
# Out:
#      property_type               society      sector  price  price_per_sqft  \
# 2932         house           independent     manesar   1.10          6173.0
# 2939         house           independent     manesar   0.80          6667.0
# 2941         house              shivpuri    sector 7   2.80         12444.0
# 2944         house           independent    sector 7   1.16         11717.0
# 2988         house           independent   sector 12   2.50         13889.0
# 2997         house  bhim nagar, sector 6    sector 6   0.85         14096.0
# 3047         house           independent    sector 3   1.10         10000.0
# 3070         house           independent   sector 12   0.65          6500.0
# 3084         house           independent  sector 105   1.10         12222.0
# 3140         house           independent   sector 17   0.32          5664.0
# 3174         house           independent    sector 2   0.98          9074.0
# ...

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)].shape
# Out:
# (13, 24)

# %%
df=df[~((df['area_room_ratio']<250) & (df['bedRoom']>4))]

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df.shape
# Out:
# (3494, 24)

# %%
df.to_csv('../CSV Files/Gurgaon_properties_outlier_treated.csv',index=False)
