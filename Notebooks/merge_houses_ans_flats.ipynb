# %%
import numpy as np
import pandas as pd

# %%
flats=pd.read_csv('../CSV Files/flats_cleaned.csv')
houses=pd.read_csv('../CSV Files/house_cleaned.csv')

# %%
df=pd.concat([flats,houses],ignore_index=True)

# %%
df.sample(5)
# Out:
#      property_type                 society     sector  price  price_per_sqft  \
# 2629          flat          avl 36 gurgaon  sector 36   0.36          8990.0
# 74            flat  bestech park view city  sector 49   2.70         12505.0
# 1037          flat            tulip violet  sector 69   1.80          8955.0
# 3127         house         naman residency   sector 4   0.50         11111.0
# 3445         house             independent  sector 47   5.25         11666.0
#
#         area                                       areaWithType  bedRoom  \
# 2629   400.0  Super Built up area 406(37.72 sq.m.)Carpet are...        1
# 74    2159.0             Super Built up area 2159(200.58 sq.m.)        3
# 1037  2010.0             Super Built up area 2010(186.74 sq.m.)        4
# 3127   450.0                         Plot area 450(41.81 sq.m.)        2
# 3445  4500.0  Plot area 1944(180.6 sq.m.)Built Up area: 4650...        9
#
# ...

# %%
df.to_csv('../CSV Files/Gurgaon_properties.csv',index=False)

# %%
df.shape
# Out:
# (3619, 17)
